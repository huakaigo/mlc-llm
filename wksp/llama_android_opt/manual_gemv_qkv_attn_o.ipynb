# %%
import os
import tvm
from tvm.script import ir as I
from tvm.script import tir as T
from tvm import autotvm, auto_scheduler
from tvm.autotvm.tuner import XGBTuner, GATuner, RandomTuner, GridSearchTuner
from tvm import meta_schedule as ms
from tvm.ir import IRModule
from tvm import relax
from tvm import rpc
from tvm.contrib import utils, ndk
x_shape = 4096
w_w_x = 512
w_s_x = 128
w_y = 4096
func_name = "main"
@I.ir_module
class ModuleSrc:
    @T.prim_func(private=False)
    # fused_fused_decode8_fused_matmul5_add
    def main(lv15: T.Buffer((T.int64(512), T.int64(4096)), "uint32"), lv16: T.Buffer((T.int64(128), T.int64(4096)), "float16"), lv14: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), lv1613: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), p_output0_intermediate: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")):
        T.func_attr({"tir.noalias": T.bool(True)})
        # with T.block("root"):
        p_output0_intermediate_1 = T.alloc_buffer((T.int64(4096), T.int64(4096)), "float16")
        var_matmul_intermediate = T.alloc_buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")
        for i, j in T.grid(T.int64(4096), T.int64(4096)):
            with T.block("decode"):
                v_i, v_j = T.axis.remap("SS", [i, j])
                T.reads(lv15[v_i // T.int64(8), v_j], lv16[v_i // T.int64(32), v_j])
                T.writes(p_output0_intermediate_1[v_i, v_j])
                p_output0_intermediate_1[v_i, v_j] = (T.Cast("float16", T.bitwise_and(T.shift_right(lv15[v_i // T.int64(8), v_j], T.Cast("uint32", v_i % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv16[v_i // T.int64(32), v_j]
        for i0, i1, i2, k in T.grid(T.int64(1), T.int64(1), T.int64(4096), T.int64(4096)):
            with T.block("matmul"):
                v_i0, v_i1, v_i2, v_k = T.axis.remap("SSSR", [i0, i1, i2, k])
                T.reads(lv14[v_i0, v_i1, v_k], p_output0_intermediate_1[v_k, v_i2])
                T.writes(var_matmul_intermediate[v_i0, v_i1, v_i2])
                with T.init():
                    var_matmul_intermediate[v_i0, v_i1, v_i2] = T.float16(0)
                var_matmul_intermediate[v_i0, v_i1, v_i2] = var_matmul_intermediate[v_i0, v_i1, v_i2] + lv14[v_i0, v_i1, v_k] * p_output0_intermediate_1[v_k, v_i2]
        for ax0, ax1, ax2 in T.grid(T.int64(1), T.int64(1), T.int64(4096)):
            with T.block("T_add"):
                v_ax0, v_ax1, v_ax2 = T.axis.remap("SSS", [ax0, ax1, ax2])
                T.reads(lv1613[v_ax0, v_ax1, v_ax2], var_matmul_intermediate[v_ax0, v_ax1, v_ax2])
                T.writes(p_output0_intermediate[v_ax0, v_ax1, v_ax2])
                p_output0_intermediate[v_ax0, v_ax1, v_ax2] = lv1613[v_ax0, v_ax1, v_ax2] + var_matmul_intermediate[v_ax0, v_ax1, v_ax2]

@I.ir_module
class ModuleToManual:
    @T.prim_func(private=False)
    # fused_fused_decode8_fused_matmul5_add
    def main(lv15: T.Buffer((T.int64(512), T.int64(4096)), "uint32"), lv16: T.Buffer((T.int64(128), T.int64(4096)), "float16"), lv14: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), lv1613: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), p_output0_intermediate: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")):
        T.func_attr({"tir.noalias": T.bool(True)})
        # with T.block("root"):
        p_output0_intermediate_1 = T.alloc_buffer((T.int64(4096), T.int64(4096)), "float16")
        var_matmul_intermediate = T.alloc_buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")
        for i, j in T.grid(T.int64(4096), T.int64(4096)):
            with T.block("decode"):
                v_i, v_j = T.axis.remap("SS", [i, j])
                T.reads(lv15[v_i // T.int64(8), v_j], lv16[v_i // T.int64(32), v_j])
                T.writes(p_output0_intermediate_1[v_i, v_j])
                p_output0_intermediate_1[v_i, v_j] = (T.Cast("float16", T.bitwise_and(T.shift_right(lv15[v_i // T.int64(8), v_j], T.Cast("uint32", v_i % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv16[v_i // T.int64(32), v_j]
        for i0, i1, i2, k in T.grid(T.int64(1), T.int64(1), T.int64(4096), T.int64(4096)):
            with T.block("matmul"):
                v_i0, v_i1, v_i2, v_k = T.axis.remap("SSSR", [i0, i1, i2, k])
                T.reads(lv14[v_i0, v_i1, v_k], p_output0_intermediate_1[v_k, v_i2])
                T.writes(var_matmul_intermediate[v_i0, v_i1, v_i2])
                with T.init():
                    var_matmul_intermediate[v_i0, v_i1, v_i2] = T.float16(0)
                var_matmul_intermediate[v_i0, v_i1, v_i2] = var_matmul_intermediate[v_i0, v_i1, v_i2] + lv14[v_i0, v_i1, v_k] * p_output0_intermediate_1[v_k, v_i2]
        for ax0, ax1, ax2 in T.grid(T.int64(1), T.int64(1), T.int64(4096)):
            with T.block("T_add"):
                v_ax0, v_ax1, v_ax2 = T.axis.remap("SSS", [ax0, ax1, ax2])
                T.reads(lv1613[v_ax0, v_ax1, v_ax2], var_matmul_intermediate[v_ax0, v_ax1, v_ax2])
                T.writes(p_output0_intermediate[v_ax0, v_ax1, v_ax2])
                p_output0_intermediate[v_ax0, v_ax1, v_ax2] = lv1613[v_ax0, v_ax1, v_ax2] + var_matmul_intermediate[v_ax0, v_ax1, v_ax2]

# %%
## ref to mlc-llm/dispatch/dispatch_tir_operator_adreno.py
## 参数: vf	vi	tx	bx	cost(ms)
##      2	4	64	32	0.375696   best
##      2	8	64	32	0.381664   origin
def sch_fused_decode4_fused_matmul4_add1(func):
    sch = tvm.tir.Schedule(func)
    b0 = sch.get_block(name="decode", func_name="main")
    b1 = sch.get_block(name="matmul", func_name="main")
    l2, l3, l4, l5 = sch.get_loops(block=b1)
    l6 = sch.fuse(l2, l3, l4, preserve_unit_iters=True)
    v7, v8, v9 = sch.sample_perfect_tile(
        loop=l6, n=3, max_innermost_factor=4, decision=[32, 64, 2]
    )
    l10, l11, l12 = sch.split(loop=l6, factors=[v7, v8, v9], preserve_unit_iters=True)
    v13, v14, v15 = sch.sample_perfect_tile(
        loop=l5, n=3, max_innermost_factor=8, decision=[128, 4, 8]
    )
    l16, l17, l18 = sch.split(
        loop=l5, factors=[v13, v14, v15], preserve_unit_iters=True
    )
    sch.reorder(l10, l11, l16, l17, l18, l12)
    sch.bind(loop=l10, thread_axis="blockIdx.x")
    sch.bind(loop=l11, thread_axis="threadIdx.x")
    sch.compute_inline(block=b0)
    b19 = sch.cache_write(block=b1, write_buffer_index=0, storage_scope="local")
    sch.reverse_compute_at(block=b19, loop=l11, preserve_unit_loops=True, index=-1)
    b20 = sch.cache_read(block=b1, read_buffer_index=1, storage_scope="local")
    b21 = sch.cache_read(block=b1, read_buffer_index=2, storage_scope="local")
    b22 = sch.cache_read(block=b1, read_buffer_index=0, storage_scope="shared")
    sch.compute_at(block=b22, loop=l11, preserve_unit_loops=True, index=-1)
    v23 = sch.sample_categorical(
        candidates=[1, 2, 4, 8], probs=[0.25, 0.25, 0.25, 0.25], decision=3
    )
    sch.annotate(
        block_or_loop=b22, ann_key="meta_schedule.cooperative_fetch", ann_val=v23
    )
    sch.compute_at(block=b20, loop=l17, preserve_unit_loops=True, index=-1)
    sch.compute_at(block=b21, loop=l16, preserve_unit_loops=True, index=-1)
    l24, l25, l26, l27, l28, l29 = sch.get_loops(block=b20)
    sch.vectorize(loop=l29)
    l30, l31, l32, l33, l34 = sch.get_loops(block=b21)
    sch.vectorize(loop=l34)
    l35, l36, l37, l38, l39 = sch.get_loops(block=b19)
    sch.vectorize(loop=l39)
    sch.vectorize(loop=l12)
    b40 = sch.decompose_reduction(block=b1, loop=l16)
    b41 = sch.get_block(name="T_add", func_name="main")
    sch.reverse_compute_inline(block=b41)
    sch.enter_postproc()
    sch.unannotate(block_or_loop=b22, ann_key="meta_schedule.cooperative_fetch")
    l42, l43, l44, l45, l46 = sch.get_loops(block=b22)
    l47, l48, l49 = sch.split(loop=l46, factors=[None, 64, 4], preserve_unit_iters=True)
    sch.vectorize(loop=l49)
    sch.bind(loop=l48, thread_axis="threadIdx.x")
    return sch.mod["main"].with_attr("tir.is_scheduled", 1)


sch_manual = tvm.tir.Schedule(ModuleToManual)
sch_manual.mod['main'] = sch_fused_decode4_fused_matmul4_add1(sch_manual.mod[func_name])
print("\n\n=================final mod===============================")
print(sch_manual.mod.script())
print("\n\n=================kernel source===============================")
rt_mod = tvm.build(sch_manual.mod, target="opencl")
print(rt_mod.imported_modules[0].get_source())
# Out:
# =================final mod===============================
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(lv15: T.Buffer((T.int64(512), T.int64(4096)), "uint32"), lv16: T.Buffer((T.int64(128), T.int64(4096)), "float16"), lv14: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), lv1613: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), p_output0_intermediate: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")):
#         T.func_attr({"tir.is_scheduled": 1, "tir.noalias": T.bool(True)})
#         # with T.block("root"):
#         var_matmul_intermediate_local = T.alloc_buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16", scope="local")
#         lv15_local = T.alloc_buffer((T.int64(512), T.int64(4096)), "uint32", scope="local")
#         lv16_local = T.alloc_buffer((T.int64(128), T.int64(4096)), "float16", scope="local")
#         lv14_shared = T.alloc_buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16", scope="shared")
#         for i0_i1_i2_fused_0 in T.thread_binding(T.int64(32), thread="blockIdx.x"):
#             for i0_i1_i2_fused_1 in T.thread_binding(T.int64(64), thread="threadIdx.x"):
#                 for ax0, ax1, ax2_0 in T.grid(T.int64(1), T.int64(1), T.int64(8)):
#                     for ax2_1 in T.thread_binding(T.int64(64), thread="threadIdx.x"):
#                         for ax2_2 in T.vectorized(T.int64(8)):
#                             with T.block("lv14_shared"):
#                                 v0, v1 = T.axis.remap("SS", [ax0, ax1])
#                                 v2 = T.axis.spatial(T.int64(4096), ax2_0 * T.int64(512) + ax2_1 * T.int64(8) + ax2_2)
#                                 T.reads(lv14[v0, v1, v2])
#                                 T.writes(lv14_shared[v0, v1, v2])
#                                 lv14_shared[v0, v1, v2] = lv14[v0, v1, v2]
#                 for i0_i1_i2_fused_2_init in T.vectorized(T.int64(2)):
#                     with T.block("matmul_init"):
#                         v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
#                         v_i1 = T.axis.spatial(T.int64(1), T.int64(0))
#                         v_i2 = T.axis.spatial(T.int64(4096), i0_i1_i2_fused_0 * T.int64(128) + i0_i1_i2_fused_1 * T.int64(2) + i0_i1_i2_fused_2_init)
#                         T.reads()
#                         T.writes(var_matmul_intermediate_local[v_i0, v_i1, v_i2])
#                         var_matmul_intermediate_local[v_i0, v_i1, v_i2] = T.float16(0)
#                 for k_0 in range(T.int64(128)):
#                     for ax0 in range(T.int64(1)):
#                         for ax1 in T.vectorized(T.int64(2)):
#                             with T.block("lv16_local"):
#                                 v0 = T.axis.spatial(T.int64(128), k_0 + ax0)
#                                 v1 = T.axis.spatial(T.int64(4096), i0_i1_i2_fused_0 * T.int64(128) + i0_i1_i2_fused_1 * T.int64(2) + ax1)
#                                 T.reads(lv16[v0, v1])
#                                 T.writes(lv16_local[v0, v1])
#                                 lv16_local[v0, v1] = lv16[v0, v1]
#                     for k_1 in range(T.int64(4)):
#                         for ax0 in range(T.int64(1)):
#                             for ax1 in T.vectorized(T.int64(2)):
#                                 with T.block("lv15_local"):
#                                     v0 = T.axis.spatial(T.int64(512), k_0 * T.int64(4) + k_1 + ax0)
#                                     v1 = T.axis.spatial(T.int64(4096), i0_i1_i2_fused_0 * T.int64(128) + i0_i1_i2_fused_1 * T.int64(2) + ax1)
#                                     T.reads(lv15[v0, v1])
#                                     T.writes(lv15_local[v0, v1])
#                                     lv15_local[v0, v1] = lv15[v0, v1]
#                         for k_2 in range(T.int64(8)):
#                             for i0_i1_i2_fused_2 in T.vectorized(T.int64(2)):
#                                 with T.block("matmul_update"):
#                                     v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
#                                     v_i1 = T.axis.spatial(T.int64(1), T.int64(0))
#                                     v_i2 = T.axis.spatial(T.int64(4096), i0_i1_i2_fused_0 * T.int64(128) + i0_i1_i2_fused_1 * T.int64(2) + i0_i1_i2_fused_2)
#                                     v_k = T.axis.reduce(T.int64(4096), k_0 * T.int64(32) + k_1 * T.int64(8) + k_2)
#                                     T.reads(var_matmul_intermediate_local[v_i0, v_i1, v_i2], lv14_shared[v_i0, v_i1, v_k], lv15_local[v_k // T.int64(8), v_i2], lv16_local[v_k // T.int64(32), v_i2])
#                                     T.writes(var_matmul_intermediate_local[v_i0, v_i1, v_i2])
#                                     var_matmul_intermediate_local[v_i0, v_i1, v_i2] = var_matmul_intermediate_local[v_i0, v_i1, v_i2] + lv14_shared[v_i0, v_i1, v_k] * ((T.Cast("float16", T.bitwise_and(T.shift_right(lv15_local[v_k // T.int64(8), v_i2], T.Cast("uint32", v_k % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv16_local[v_k // T.int64(32), v_i2])
#                 for ax0, ax1 in T.grid(T.int64(1), T.int64(1)):
#                     for ax2 in T.vectorized(T.int64(2)):
#                         with T.block("var_matmul_intermediate_local"):
#                             v0, v1 = T.axis.remap("SS", [ax0, ax1])
#                             v2 = T.axis.spatial(T.int64(4096), i0_i1_i2_fused_0 * T.int64(128) + i0_i1_i2_fused_1 * T.int64(2) + ax2)
#                             T.reads(lv1613[v0, v1, v2], var_matmul_intermediate_local[v0, v1, v2])
#                             T.writes(p_output0_intermediate[v0, v1, v2])
#                             p_output0_intermediate[v0, v1, v2] = lv1613[v0, v1, v2] + var_matmul_intermediate_local[v0, v1, v2]
#
#
# =================kernel source===============================
# // Function: main_kernel
# #ifdef cl_khr_fp16
# #pragma OPENCL EXTENSION cl_khr_fp16 : enable
# #elif defined(cl_amd_fp16)
# #pragma OPENCL EXTENSION cl_amd_fp16 : enable
# #else
# #error "Half precision floating point not supported by OpenCL implementation on your device."
# #endif
#
# __kernel void main_kernel(__global half* restrict lv14, __global uint* restrict lv15, __global half* restrict lv16, __global half* restrict lv1613, __global half* restrict p_output0_intermediate) {
#   __local half lv14_shared[4096];
#   half2 var_matmul_intermediate_local[1];
#   half2 lv16_local[1];
#   uint2 lv15_local[1];
#   for (int ax2_0 = 0; ax2_0 < 8; ++ax2_0) {
#     vstore8(vload8(0, lv14 + ((ax2_0 * 512) + ((convert_int(get_local_id(0))) * 8))), 0, lv14_shared + ((ax2_0 * 512) + ((convert_int(get_local_id(0))) * 8)));
#   }
#   var_matmul_intermediate_local[0] = ((half2)((half)0.000000e+00f, (half)0.000000e+00f));
#   barrier(CLK_LOCAL_MEM_FENCE);
#   for (int k_0 = 0; k_0 < 128; ++k_0) {
#     lv16_local[0] = vload2(0, lv16 + (((k_0 * 4096) + ((convert_int(get_group_id(0))) * 128)) + ((convert_int(get_local_id(0))) * 2)));
#     for (int k_1 = 0; k_1 < 4; ++k_1) {
#       lv15_local[0] = vload2(0, lv15 + ((((k_0 * 16384) + (k_1 * 4096)) + ((convert_int(get_group_id(0))) * 128)) + ((convert_int(get_local_id(0))) * 2)));
#       for (int k_2 = 0; k_2 < 8; ++k_2) {
#         var_matmul_intermediate_local[0] = (var_matmul_intermediate_local[0] + (((half2)(lv14_shared[(((k_0 * 32) + (k_1 * 8)) + k_2)], lv14_shared[(((k_0 * 32) + (k_1 * 8)) + k_2)])) * (((convert_half2(((lv15_local[0]  >>  ((uint2)(((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4))))  &  ((uint2)((uint)15, (uint)15))))) - ((half2)((half)7.000000e+00f, (half)7.000000e+00f))) * lv16_local[0])));
#       }
#     }
#   }
#   vstore2((vload2(0, lv1613 + (((convert_int(get_group_id(0))) * 128) + ((convert_int(get_local_id(0))) * 2))) + var_matmul_intermediate_local[0]), 0, p_output0_intermediate + (((convert_int(get_group_id(0))) * 128) + ((convert_int(get_local_id(0))) * 2)));
# }

# %%
# run and compare with cuda
import numpy as np
def _detect_local_cuda():
    dev = tvm.cuda()
    if not dev.exist:
        return None
    return tvm.target.Target(
        {
            "kind": "cuda",
            "max_shared_memory_per_block": dev.max_shared_memory_per_block,
            "max_threads_per_block": dev.max_threads_per_block,
            "thread_warp_size": dev.warp_size,
            "registers_per_block": 65536,
            "arch": "sm_" + tvm.cuda().compute_version.replace(".", ""),
        }
    )
# target = tvm.target.Target("cuda", host="llvm")
target = _detect_local_cuda()

print(target)
# 定义计算任务
dev = tvm.cuda(0)

num_flop = 1228406784
W_w_np = np.random.uniform(size=(w_w_x, w_y)).astype("uint32")
W_s_np = np.random.uniform(size=(w_s_x, w_y)).astype("float16")
Input_np = np.random.uniform(size=(1, 1, x_shape)).astype("float16")
B_np = np.random.uniform(size=(1, 1, w_y)).astype("float16")
# W_w_np = np.ones((w_w_x, w_y), np.uint32) * 1#.astype("uint32")
# W_s_np = np.ones((w_s_x, w_y), np.float16) * 1#.astype("float16") * 2
# Input_np = np.ones((1, 1, x_shape), np.float16)#.astype("float16")
Output_nd = tvm.nd.array(np.zeros((1, 1, w_y), dtype="float16"), dev)
def numpy_caculate():
    test_cols = 10
    output = np.zeros((1, 1, test_cols), dtype = np.float16)
    W_w_inv_np = np.transpose(W_w_np)
    W_s_inv_np = np.transpose(W_s_np)
    for i in range(test_cols):
        for r in range(x_shape):
            temp = Input_np[0][0][r] * np.float16((W_w_inv_np[i][r // 8] >> ((r % 8) * 4) & (15)) - np.float16(7.0)) * W_s_inv_np[i][r // 32]
            output[0][0][i] = output[0][0][i] + temp
        output[0][0][i] = output[0][0][i] + B_np[0][0][i]
    print(output)
    output = np.zeros((1, 1, test_cols), dtype = np.float16)
    for i in range(test_cols):
        for r in range(x_shape):
            temp = Input_np[0][0][r] * np.float16((W_w_np[r // 8][i] >> ((r % 8) * 4) & (15)) - np.float16(7.0)) * W_s_np[r // 32][i]
            temp_output = output[0][0][i]
            output[0][0][i] = temp_output + temp
            # print(f"{temp_output} + {temp} = {output[0][0][i]}")
        output[0][0][i] = output[0][0][i] + B_np[0][0][i]
    print(output)
numpy_caculate()
def print_npdata(np_data: np.ndarray) :
    print(np_data)
    print_num = 20
    d = np_data.flatten()
    p_size = print_num if d.size > print_num else d.size
    print(d[:p_size])
# Out:
# cuda -keys=cuda,gpu -arch=sm_61 -max_num_threads=1024 -max_shared_memory_per_block=49152 -max_threads_per_block=1024 -registers_per_block=65536 -thread_warp_size=32
# [[[-6608. -6324. -6528. -7140. -7052. -6308. -6240. -6256. -6644. -6760.]]]
# [[[-6608. -6324. -6528. -7140. -7052. -6308. -6240. -6256. -6644. -6760.]]]

# %%
# cuda未优化版本测试
sch = tvm.tir.Schedule(ModuleSrc)
with target:
    src_gpu_mod = tvm.tir.transform.DefaultGPUSchedule()(sch.mod) ##
rt_mod = tvm.build(src_gpu_mod, target="cuda")
W_w_nd = tvm.nd.array(W_w_np, dev)
W_s_nd = tvm.nd.array(W_s_np, dev)
B_nd = tvm.nd.array(B_np, dev)
Input_nd = tvm.nd.array(Input_np, dev)
Output_nd = tvm.nd.array(np.zeros((1, 1, w_y), dtype="float16"), dev)
evaluator = rt_mod.time_evaluator("main", dev, number=100)
print("manual_evaluator GEMV-Blocking: %f GFLOPS" % (num_flop / evaluator(W_w_nd, W_s_nd, Input_nd, B_nd, Output_nd).mean / 1e9))
# print(Output_nd.numpy())
print_npdata(Output_nd.numpy())
# Out:
# manual_evaluator GEMV-Blocking: 296.241723 GFLOPS
# [[[-6996. -6048. -6820. ... -6844. -6384. -6200.]]]
# [-6996. -6048. -6820. -6752. -6740. -6284. -7320. -6668. -7044. -6704.
#  -6904. -6592. -6828. -6576. -5848. -6592. -6680. -6060. -6352. -6080.]

# %%
os.environ["TVM_NDK_CC"]="/home/sensetime/Android/Sdk/ndk/25.2.9519653/toolchains/llvm/prebuilt/linux-x86_64/bin/aarch64-linux-android33-clang++"
target = tvm.target.Target("opencl -device=adreno", host="llvm -mtriple=aarch64-linux-gnu")
device_key="android"
rpc_host = "10.4.236.32"
rpc_port = 9190
comp_target = tvm.target.Target("opencl", host="llvm -mtriple=aarch64-linux-android")  # TODO: Only support arm64 for now

def test_opencl(mod: tvm.IRModule, name_hint: str):
    # mod = tvm.lower(sch_manual.mod)
    print("Build ...")
    android_rt_mod = tvm.build(mod, target="opencl", target_host="llvm -mtriple=aarch64-linux-android")
    # print(android_rt_mod.imported_modules[0].get_source())
    temp = utils.tempdir()
    path_dso_cl = temp.relpath("dev_lib_cl.so")
    android_rt_mod.export_library(path_dso_cl, ndk.create_shared)

    print("Run GPU(OpenCL Flavor) test ...")
    # Establish remote connection with target hardware

    tracker = rpc.connect_tracker(rpc_host, rpc_port)
    remote = tracker.request(device_key, priority=0, session_timeout=60)
    print("Connect to device done.")
    dev = remote.cl(0)
    remote.upload(path_dso_cl)
    f1 = remote.load_module("dev_lib_cl.so")

    W_w_nd = tvm.nd.array(W_w_np, dev)
    W_s_nd = tvm.nd.array(W_s_np, dev)
    B_nd = tvm.nd.array(B_np, dev)
    Input_nd = tvm.nd.array(Input_np, dev)
    Output_nd = tvm.nd.array(np.zeros((1, 1, w_y), dtype="float16"), dev)
    test_number=32
    time_f = f1.time_evaluator(f1.entry_name, dev, number=test_number)
    cost = time_f(W_w_nd, W_s_nd, Input_nd, B_nd, Output_nd).mean
    print("evaluator[%s] GEMV-Blocking: %fms with loop %d" % (name_hint, cost * 1000, test_number))
    print("evaluator[%s] GEMV-Blocking: %fGFLOPS" % (name_hint, num_flop / cost / 1e9))
    print_npdata(Output_nd.numpy())

    return cost*1000 # unit: ms

# %%
# 未优化版本opencl测试
from tvm import dlight as dl
sch = tvm.tir.Schedule(ModuleSrc)
with target:
    # src_gpu_mod = tvm.tir.transform.DefaultGPUSchedule()(sch.mod) ##
    mod_deploy = dl.ApplyDefaultSchedule(  # pylint: disable=not-callable
        dl.gpu.Matmul(),
        dl.gpu.GEMV(),
        dl.gpu.Reduction(),
        dl.gpu.GeneralReduction(),
        dl.gpu.Fallback(),
    )(sch.mod)
src_output = test_opencl(mod_deploy, "source")
# print_npdata(src_output)
# Out:
# Build ...
# Run GPU(OpenCL Flavor) test ...
# /data/workspace/llm/github/new_wksp/tvm-unity/python/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# Connect to device done.
# evaluator[source] GEMV-Blocking: 2.336176ms with loop 32
# evaluator[source] GEMV-Blocking: 525.819452GFLOPS
# [-7424. -6944. -6884. -7256. -7064. -7084. -7672. -7484. -6880. -6688.]

# %%
#优化版本opencl测试
# print(sch_manual.mod)
opt_output = test_opencl(sch_manual.mod, "opted")
# print_npdata(opt_output)
# np.testing.assert_equal(opt_output, src_output)
# Out:
# Build ...
# /data/workspace/llm/github/new_wksp/tvm-unity/python/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[opted] GEMV-Blocking: 0.381056ms with loop 32
# evaluator[opted] GEMV-Blocking: 3223.690964GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]

# %%
# 自动搜索
def auto_tune(record_file: str):
    from typing import Union
    def search(vf: int, vi: int, tx: int, bx: Union[int, None] = None):
        """search by workgroup

        Args:
            blockIdxX (_type_): blockIdx.x
            threadIdxX (_type_): threadIdx.x
            vectorize_output (_type_): 输出的vectorize参数, 决定单线程输出多少个结果
            vectorize_input (list, optional): 输入X拷贝到shared_memory时的vectorize参数, 一般为4或8

        Returns:
            _type_: _description_
        """
        @I.ir_module
        class ModuleToManual:
            @T.prim_func(private=False)
            def main(lv15: T.Buffer((T.int64(512), T.int64(4096)), "uint32"), lv16: T.Buffer((T.int64(128), T.int64(4096)), "float16"), lv14: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), lv1613: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16"), p_output0_intermediate: T.Buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")):
                T.func_attr({"tir.noalias": T.bool(True)})
                # with T.block("root"):
                p_output0_intermediate_1 = T.alloc_buffer((T.int64(4096), T.int64(4096)), "float16")
                var_matmul_intermediate = T.alloc_buffer((T.int64(1), T.int64(1), T.int64(4096)), "float16")
                for i, j in T.grid(T.int64(4096), T.int64(4096)):
                    with T.block("decode"):
                        v_i, v_j = T.axis.remap("SS", [i, j])
                        T.reads(lv15[v_i // T.int64(8), v_j], lv16[v_i // T.int64(32), v_j])
                        T.writes(p_output0_intermediate_1[v_i, v_j])
                        p_output0_intermediate_1[v_i, v_j] = (T.Cast("float16", T.bitwise_and(T.shift_right(lv15[v_i // T.int64(8), v_j], T.Cast("uint32", v_i % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv16[v_i // T.int64(32), v_j]
                for i0, i1, i2, k in T.grid(T.int64(1), T.int64(1), T.int64(4096), T.int64(4096)):
                    with T.block("matmul"):
                        v_i0, v_i1, v_i2, v_k = T.axis.remap("SSSR", [i0, i1, i2, k])
                        T.reads(lv14[v_i0, v_i1, v_k], p_output0_intermediate_1[v_k, v_i2])
                        T.writes(var_matmul_intermediate[v_i0, v_i1, v_i2])
                        with T.init():
                            var_matmul_intermediate[v_i0, v_i1, v_i2] = T.float16(0)
                        var_matmul_intermediate[v_i0, v_i1, v_i2] = var_matmul_intermediate[v_i0, v_i1, v_i2] + lv14[v_i0, v_i1, v_k] * p_output0_intermediate_1[v_k, v_i2]
                for ax0, ax1, ax2 in T.grid(T.int64(1), T.int64(1), T.int64(4096)):
                    with T.block("T_add"):
                        v_ax0, v_ax1, v_ax2 = T.axis.remap("SSS", [ax0, ax1, ax2])
                        T.reads(lv1613[v_ax0, v_ax1, v_ax2], var_matmul_intermediate[v_ax0, v_ax1, v_ax2])
                        T.writes(p_output0_intermediate[v_ax0, v_ax1, v_ax2])
                        p_output0_intermediate[v_ax0, v_ax1, v_ax2] = lv1613[v_ax0, v_ax1, v_ax2] + var_matmul_intermediate[v_ax0, v_ax1, v_ax2]

        sch = tvm.tir.Schedule(ModuleToManual)
        b0 = sch.get_block(name="decode", func_name="main")
        b1 = sch.get_block(name="matmul", func_name="main")
        l2, l3, l4, l5 = sch.get_loops(block=b1)
        l6 = sch.fuse(l2, l3, l4, preserve_unit_iters=True)
        v7, v8, v9 = sch.sample_perfect_tile(
            loop=l6, n=3, max_innermost_factor=8, decision=[bx, tx, vf]
        )
        l10, l11, l12 = sch.split(loop=l6, factors=[v7, v8, v9], preserve_unit_iters=True)
        v13, v14, v15 = sch.sample_perfect_tile(
            loop=l5, n=3, max_innermost_factor=8, decision=[128, 4, 8]
        )
        l16, l17, l18 = sch.split(
            loop=l5, factors=[v13, v14, v15], preserve_unit_iters=True
        )
        sch.reorder(l10, l11, l16, l17, l18, l12)
        sch.bind(loop=l10, thread_axis="blockIdx.x")
        sch.bind(loop=l11, thread_axis="threadIdx.x")
        sch.compute_inline(block=b0)
        b19 = sch.cache_write(block=b1, write_buffer_index=0, storage_scope="local")
        sch.reverse_compute_at(block=b19, loop=l11, preserve_unit_loops=True, index=-1)
        b20 = sch.cache_read(block=b1, read_buffer_index=1, storage_scope="local")
        b21 = sch.cache_read(block=b1, read_buffer_index=2, storage_scope="local")
        b22 = sch.cache_read(block=b1, read_buffer_index=0, storage_scope="shared")
        sch.compute_at(block=b22, loop=l11, preserve_unit_loops=True, index=-1)
        v23 = sch.sample_categorical(
            candidates=[1, 2, 4, 8], probs=[0.25, 0.25, 0.25, 0.25], decision=3
        )
        sch.annotate(
            block_or_loop=b22, ann_key="meta_schedule.cooperative_fetch", ann_val=v23
        )
        sch.compute_at(block=b20, loop=l17, preserve_unit_loops=True, index=-1)
        sch.compute_at(block=b21, loop=l16, preserve_unit_loops=True, index=-1)
        l24, l25, l26, l27, l28, l29 = sch.get_loops(block=b20)
        sch.vectorize(loop=l29)
        l30, l31, l32, l33, l34 = sch.get_loops(block=b21)
        sch.vectorize(loop=l34)
        l35, l36, l37, l38, l39 = sch.get_loops(block=b19)
        sch.vectorize(loop=l39)
        sch.vectorize(loop=l12)
        b40 = sch.decompose_reduction(block=b1, loop=l16)
        b41 = sch.get_block(name="T_add", func_name="main")
        sch.reverse_compute_inline(block=b41)
        sch.enter_postproc()
        sch.unannotate(block_or_loop=b22, ann_key="meta_schedule.cooperative_fetch")
        l42, l43, l44, l45, l46 = sch.get_loops(block=b22)
        l47, l48, l49 = sch.split(loop=l46, factors=[None, tx, vi], preserve_unit_iters=True)
        sch.vectorize(loop=l49)
        sch.bind(loop=l48, thread_axis="threadIdx.x")
        return sch.mod
    vec_factor = [2, 4, 8]
    vec_input = [2, 4, 8]
    blockx = [None]
    threadx = [8, 16, 32, 64, 128,  256, 512, 1024]
    task_index = 0
    total_task_num = len(vec_factor)*len(vec_input)*len(blockx)*len(threadx)
    records = {}
    print(f"Total tasks: {total_task_num}")
    write_interval = 5
    from prettytable import PrettyTable
    table = PrettyTable()
    table.field_names = ["vf", "vi", "tx", "bx", "cost(ms)"]
    for vf in vec_factor:
        for vi in vec_input:
            for tx in threadx:
                    task_index = task_index + 1
                    import math
                    bx = w_y /(vf * tx)
                    if tx * vf > w_y or tx > 1024:
                        print(f"search record [{task_index}/{total_task_num}]: skip {vf} {vi} {tx} {bx}")
                        continue
                    print(f"search record [{task_index}/{total_task_num}]: start run {vf} {vi} {tx} {bx}")
                    bx_real = int(bx)
                    if w_y % (vf * tx) != 0:
                        bx_real = None
                    mod_deploy = search(vf, vi, tx, bx_real)
                    cost = test_opencl(mod_deploy, "search")
                    print("=====")
                    records[(vf, vi, tx, bx)] = cost

                    table.add_row([vf, vi, tx, bx, cost])
                    if task_index % write_interval == 0:
                        with open(record_file, 'wt') as f:
                            f.write(table.get_csv_string())
    print("================================")
    print(table)
    
    # record_sorted = sorted(record.items(), key=lambda x: x[1][0], reverse=True)
auto_tune("./manual_tune/attn_o_proj_tune_record_1.csv")
# Out:
# Total tasks: 72
# search record [1/72]: start run 2 2 8 256.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 2.180464ms with loop 32
# evaluator[search] GEMV-Blocking: 563.369441GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [2/72]: start run 2 2 16 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.075368ms with loop 32
# evaluator[search] GEMV-Blocking: 1142.312942GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [3/72]: start run 2 2 32 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.718744ms with loop 32
# evaluator[search] GEMV-Blocking: 1709.101967GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [4/72]: start run 2 2 64 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.380784ms with loop 32
# evaluator[search] GEMV-Blocking: 3225.993697GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [5/72]: start run 2 2 128 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.451168ms with loop 32
# evaluator[search] GEMV-Blocking: 2722.725867GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [6/72]: start run 2 2 256 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.436784ms with loop 32
# evaluator[search] GEMV-Blocking: 2812.389611GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [7/72]: start run 2 2 512 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.511944ms with loop 32
# evaluator[search] GEMV-Blocking: 2399.494445GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [8/72]: start run 2 2 1024 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.986392ms with loop 32
# evaluator[search] GEMV-Blocking: 1245.353555GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [9/72]: start run 2 4 8 256.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 2.027936ms with loop 32
# evaluator[search] GEMV-Blocking: 605.742382GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [10/72]: start run 2 4 16 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.010768ms with loop 32
# evaluator[search] GEMV-Blocking: 1215.320216GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [11/72]: start run 2 4 32 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.689928ms with loop 32
# evaluator[search] GEMV-Blocking: 1780.485477GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [12/72]: start run 2 4 64 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.375696ms with loop 32
# evaluator[search] GEMV-Blocking: 3269.682893GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [13/72]: start run 2 4 128 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.441808ms with loop 32
# evaluator[search] GEMV-Blocking: 2780.408648GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [14/72]: start run 2 4 256 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.437248ms with loop 32
# evaluator[search] GEMV-Blocking: 2809.405152GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [15/72]: start run 2 4 512 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.510248ms with loop 32
# evaluator[search] GEMV-Blocking: 2407.470062GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [16/72]: start run 2 4 1024 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.986072ms with loop 32
# evaluator[search] GEMV-Blocking: 1245.757697GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [17/72]: start run 2 8 8 256.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.974496ms with loop 32
# evaluator[search] GEMV-Blocking: 622.136882GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [18/72]: start run 2 8 16 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.994296ms with loop 32
# evaluator[search] GEMV-Blocking: 1235.453813GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [19/72]: start run 2 8 32 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.684496ms with loop 32
# evaluator[search] GEMV-Blocking: 1794.614993GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [20/72]: start run 2 8 64 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.381664ms with loop 32
# evaluator[search] GEMV-Blocking: 3218.555546GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [21/72]: start run 2 8 128 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.443040ms with loop 32
# evaluator[search] GEMV-Blocking: 2772.676923GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [22/72]: start run 2 8 256 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.436464ms with loop 32
# evaluator[search] GEMV-Blocking: 2814.451556GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [23/72]: start run 2 8 512 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.510552ms with loop 32
# evaluator[search] GEMV-Blocking: 2406.036572GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [24/72]: start run 2 8 1024 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.089424ms with loop 32
# evaluator[search] GEMV-Blocking: 1127.574557GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [25/72]: start run 4 2 8 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.425184ms with loop 32
# evaluator[search] GEMV-Blocking: 861.928554GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [26/72]: start run 4 2 16 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.832144ms with loop 32
# evaluator[search] GEMV-Blocking: 1476.194966GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [27/72]: start run 4 2 32 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.460184ms with loop 32
# evaluator[search] GEMV-Blocking: 2669.381778GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [28/72]: start run 4 2 64 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.431544ms with loop 32
# evaluator[search] GEMV-Blocking: 2846.538902GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [29/72]: start run 4 2 128 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.561696ms with loop 32
# evaluator[search] GEMV-Blocking: 2186.960178GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [30/72]: start run 4 2 256 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.548568ms with loop 32
# evaluator[search] GEMV-Blocking: 2239.297196GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [31/72]: start run 4 2 512 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.654344ms with loop 32
# evaluator[search] GEMV-Blocking: 1877.310381GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [32/72]: start run 4 2 1024 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.223920ms with loop 32
# evaluator[search] GEMV-Blocking: 1003.665913GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [33/72]: start run 4 4 8 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.331176ms with loop 32
# evaluator[search] GEMV-Blocking: 922.798175GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [34/72]: start run 4 4 16 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.786000ms with loop 32
# evaluator[search] GEMV-Blocking: 1562.858504GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [35/72]: start run 4 4 32 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.448400ms with loop 32
# evaluator[search] GEMV-Blocking: 2739.533417GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [36/72]: start run 4 4 64 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.427816ms with loop 32
# evaluator[search] GEMV-Blocking: 2871.343718GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [37/72]: start run 4 4 128 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.555088ms with loop 32
# evaluator[search] GEMV-Blocking: 2212.994668GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [38/72]: start run 4 4 256 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.551528ms with loop 32
# evaluator[search] GEMV-Blocking: 2227.279094GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [39/72]: start run 4 4 512 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.658032ms with loop 32
# evaluator[search] GEMV-Blocking: 1866.788825GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [40/72]: start run 4 4 1024 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.226688ms with loop 32
# evaluator[search] GEMV-Blocking: 1001.401158GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [41/72]: start run 4 8 8 128.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.288832ms with loop 32
# evaluator[search] GEMV-Blocking: 953.116298GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [42/72]: start run 4 8 16 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.774768ms with loop 32
# evaluator[search] GEMV-Blocking: 1585.515643GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [43/72]: start run 4 8 32 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.443424ms with loop 32
# evaluator[search] GEMV-Blocking: 2770.275817GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [44/72]: start run 4 8 64 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.433712ms with loop 32
# evaluator[search] GEMV-Blocking: 2832.309883GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [45/72]: start run 4 8 128 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.548912ms with loop 32
# evaluator[search] GEMV-Blocking: 2237.893841GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [46/72]: start run 4 8 256 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.543288ms with loop 32
# evaluator[search] GEMV-Blocking: 2261.060034GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [47/72]: start run 4 8 512 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.655704ms with loop 32
# evaluator[search] GEMV-Blocking: 1873.416639GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [48/72]: start run 4 8 1024 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.347064ms with loop 32
# evaluator[search] GEMV-Blocking: 911.914196GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [49/72]: start run 8 2 8 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.657496ms with loop 32
# evaluator[search] GEMV-Blocking: 741.122020GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [50/72]: start run 8 2 16 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.984512ms with loop 32
# evaluator[search] GEMV-Blocking: 1247.731652GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [51/72]: start run 8 2 32 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.872472ms with loop 32
# evaluator[search] GEMV-Blocking: 1407.961269GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [52/72]: start run 8 2 64 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.954152ms with loop 32
# evaluator[search] GEMV-Blocking: 1287.433013GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [53/72]: start run 8 2 128 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.961752ms with loop 32
# evaluator[search] GEMV-Blocking: 1277.259402GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [54/72]: start run 8 2 256 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.289320ms with loop 32
# evaluator[search] GEMV-Blocking: 952.755549GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [55/72]: start run 8 2 512 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 2.060192ms with loop 32
# evaluator[search] GEMV-Blocking: 596.258399GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [56/72]: skip 8 2 1024 0.5
# search record [57/72]: start run 8 4 8 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.669280ms with loop 32
# evaluator[search] GEMV-Blocking: 735.890195GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [58/72]: start run 8 4 16 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.985136ms with loop 32
# evaluator[search] GEMV-Blocking: 1246.941320GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [59/72]: start run 8 4 32 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.884640ms with loop 32
# evaluator[search] GEMV-Blocking: 1388.595117GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [60/72]: start run 8 4 64 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.967096ms with loop 32
# evaluator[search] GEMV-Blocking: 1270.201494GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [61/72]: start run 8 4 128 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.971256ms with loop 32
# evaluator[search] GEMV-Blocking: 1264.761076GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [62/72]: start run 8 4 256 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.287992ms with loop 32
# evaluator[search] GEMV-Blocking: 953.737899GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [63/72]: start run 8 4 512 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 2.064264ms with loop 32
# evaluator[search] GEMV-Blocking: 595.082210GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [64/72]: skip 8 4 1024 0.5
# search record [65/72]: start run 8 8 8 64.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.646720ms with loop 32
# evaluator[search] GEMV-Blocking: 745.971862GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [66/72]: start run 8 8 16 32.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.975328ms with loop 32
# evaluator[search] GEMV-Blocking: 1259.480692GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [67/72]: start run 8 8 32 16.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.879696ms with loop 32
# evaluator[search] GEMV-Blocking: 1396.399192GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [68/72]: start run 8 8 64 8.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.949272ms with loop 32
# evaluator[search] GEMV-Blocking: 1294.051425GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [69/72]: start run 8 8 128 4.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 0.955744ms with loop 32
# evaluator[search] GEMV-Blocking: 1285.288512GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [70/72]: start run 8 8 256 2.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 1.266616ms with loop 32
# evaluator[search] GEMV-Blocking: 969.833623GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [71/72]: start run 8 8 512 1.0
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 2.057168ms with loop 32
# evaluator[search] GEMV-Blocking: 597.134888GFLOPS
# [[[-6608. -6320. -6528. ... -6312. -6348. -6816.]]]
# [-6608. -6320. -6528. -7140. -7048. -6312. -6240. -6256. -6648. -6760.
#  -7200. -5748. -6084. -6628. -6468. -6988. -6516. -7196. -6788. -6420.]
# =====
# search record [72/72]: skip 8 8 1024 0.5
# ================================
# +----+----+------+-------+--------------------+
# | vf | vi |  tx  |   bx  |      cost(ms)      |
# +----+----+------+-------+--------------------+
# | 2  | 2  |  8   | 256.0 |      2.180464      |
# | 2  | 2  |  16  | 128.0 |      1.075368      |
# | 2  | 2  |  32  |  64.0 |      0.718744      |
# | 2  | 2  |  64  |  32.0 |      0.380784      |
# | 2  | 2  | 128  |  16.0 |      0.451168      |
# | 2  | 2  | 256  |  8.0  |      0.436784      |
# | 2  | 2  | 512  |  4.0  |      0.511944      |
# | 2  | 2  | 1024 |  2.0  |      0.986392      |
# | 2  | 4  |  8   | 256.0 |      2.027936      |
# | 2  | 4  |  16  | 128.0 |      1.010768      |
# | 2  | 4  |  32  |  64.0 |      0.689928      |
# | 2  | 4  |  64  |  32.0 |      0.375696      |
# | 2  | 4  | 128  |  16.0 |      0.441808      |
# | 2  | 4  | 256  |  8.0  |      0.437248      |
# | 2  | 4  | 512  |  4.0  |      0.510248      |
# | 2  | 4  | 1024 |  2.0  |      0.986072      |
# | 2  | 8  |  8   | 256.0 |      1.974496      |
# | 2  | 8  |  16  | 128.0 |      0.994296      |
# | 2  | 8  |  32  |  64.0 |      0.684496      |
# | 2  | 8  |  64  |  32.0 |      0.381664      |
# | 2  | 8  | 128  |  16.0 |      0.44304       |
# | 2  | 8  | 256  |  8.0  |      0.436464      |
# | 2  | 8  | 512  |  4.0  |      0.510552      |
# | 2  | 8  | 1024 |  2.0  |      1.089424      |
# | 4  | 2  |  8   | 128.0 |      1.425184      |
# | 4  | 2  |  16  |  64.0 |      0.832144      |
# | 4  | 2  |  32  |  32.0 |      0.460184      |
# | 4  | 2  |  64  |  16.0 |      0.431544      |
# | 4  | 2  | 128  |  8.0  |      0.561696      |
# | 4  | 2  | 256  |  4.0  |      0.548568      |
# | 4  | 2  | 512  |  2.0  |      0.654344      |
# | 4  | 2  | 1024 |  1.0  |      1.22392       |
# | 4  | 4  |  8   | 128.0 |      1.331176      |
# | 4  | 4  |  16  |  64.0 |       0.786        |
# | 4  | 4  |  32  |  32.0 |       0.4484       |
# | 4  | 4  |  64  |  16.0 |      0.427816      |
# | 4  | 4  | 128  |  8.0  |      0.555088      |
# | 4  | 4  | 256  |  4.0  |      0.551528      |
# | 4  | 4  | 512  |  2.0  |      0.658032      |
# | 4  | 4  | 1024 |  1.0  |      1.226688      |
# | 4  | 8  |  8   | 128.0 |      1.288832      |
# | 4  | 8  |  16  |  64.0 |      0.774768      |
# | 4  | 8  |  32  |  32.0 |      0.443424      |
# | 4  | 8  |  64  |  16.0 |      0.433712      |
# | 4  | 8  | 128  |  8.0  |      0.548912      |
# | 4  | 8  | 256  |  4.0  |      0.543288      |
# | 4  | 8  | 512  |  2.0  |      0.655704      |
# | 4  | 8  | 1024 |  1.0  |      1.347064      |
# | 8  | 2  |  8   |  64.0 |      1.657496      |
# | 8  | 2  |  16  |  32.0 |      0.984512      |
# | 8  | 2  |  32  |  16.0 |      0.872472      |
# | 8  | 2  |  64  |  8.0  |      0.954152      |
# | 8  | 2  | 128  |  4.0  |      0.961752      |
# | 8  | 2  | 256  |  2.0  |      1.28932       |
# | 8  | 2  | 512  |  1.0  |      2.060192      |
# | 8  | 4  |  8   |  64.0 |      1.66928       |
# | 8  | 4  |  16  |  32.0 | 0.9851359999999999 |
# | 8  | 4  |  32  |  16.0 |      0.88464       |
# | 8  | 4  |  64  |  8.0  |      0.967096      |
# | 8  | 4  | 128  |  4.0  |      0.971256      |
# | 8  | 4  | 256  |  2.0  |      1.287992      |
# | 8  | 4  | 512  |  1.0  |      2.064264      |
# | 8  | 8  |  8   |  64.0 |      1.64672       |
# | 8  | 8  |  16  |  32.0 |      0.975328      |
# | 8  | 8  |  32  |  16.0 |      0.879696      |
# | 8  | 8  |  64  |  8.0  |      0.949272      |
# | 8  | 8  | 128  |  4.0  |      0.955744      |
# | 8  | 8  | 256  |  2.0  |      1.266616      |
# | 8  | 8  | 512  |  1.0  |      2.057168      |
# +----+----+------+-------+--------------------+

# %%
import numpy as np
target = tvm.target.Target("opencl -device=adreno", host="llvm -mtriple=aarch64-linux-gnu")
device_key="android"
rpc_host = "10.158.176.30"
rpc_port = 5001
# remote = autotvm.measure.request_remote(device_key, "10.158.176.30", 5001, timeout=10000)
# dev = remote.device(str(target), 0)

# num_flop = 1228406784
# W_np = np.random.uniform(size=(512, vocab_size)).astype("uint32")
# S_np = np.random.uniform(size=(128, vocab_size)).astype("float16")
# Input_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# # Output_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# W_nd = tvm.nd.array(W_np, dev)
# S_nd = tvm.nd.array(S_np, dev)
# Input_nd = tvm.nd.array(Input_np, dev)
# Output_nd = tvm.nd.array(np.zeros((1, 1, vocab_size), dtype="float32"), dev)

# %%
rpc_config = ms.runner.RPCConfig(tracker_host=rpc_host, tracker_port=rpc_port, tracker_key = device_key)
runner= ms.runner.RPCRunner(rpc_config)
# ms.builder.LocalBuilder()
sch = tvm.tir.Schedule(ModuleSrc)
database = ms.tune_tir(
    mod=ModuleSrc,
    target=target,
    max_trials_global=64,
    num_trials_per_iter=64,
    work_dir="./tune_first",
    cost_model="xgb",
    runner = runner
)
print(len(database))
sch1 = ms.tir_integration.compile_tir(database, sch.mod, target)
print(type(sch1))

# %%
from tvm.script import relax as R
@I.ir_module
class Module:
    @R.function
    def main(A: R.Tensor((3, 4), dtype="float32"), B: R.Tensor((4, 5), dtype="float32")):
        with R.dataflow():
            lv: R.Tensor((3, 5), dtype="float32") = R.matmul(A, B)
            gv: R.Tensor((3, 5), dtype="float32") = lv
            R.output(gv)
        return gv

# %%
## auto_scheduler test
from tvm import auto_scheduler
import numpy as np
a_np = np.random.rand(3, 4).astype("float32")
b_np = np.random.rand(4, 5).astype("float32")
a_nd = tvm.runtime.NDArray(a_np)
b_nd = tvm.runtime.NDArray(b_np)
sch = tvm.tir.Schedule(Module)

params = {"A": a_np, "B": b_np}
## 报错，这里只支持relay
# tasks = auto_scheduler.extract_tasks(sch.mod, params, target=target)
tasks = ms.relax_integration.extract_tasks(sch.mod, target=target, params=params)
print(len(tasks))

# %%
from mod_deploy import Module as ModuleAll
params_all = {}
tasks_all = auto_scheduler.extract_tasks(ModuleAll, params_all, target=target)
print(len(tasks_all))

# %%
import numpy as np
log_file = "tune.json"
def _detect_local_cuda():
    dev = tvm.cuda()
    if not dev.exist:
        return None
    return tvm.target.Target(
        {
            "kind": "cuda",
            "max_shared_memory_per_block": dev.max_shared_memory_per_block,
            "max_threads_per_block": dev.max_threads_per_block,
            "thread_warp_size": dev.warp_size,
            "registers_per_block": 65536,
            "arch": "sm_" + tvm.cuda().compute_version.replace(".", ""),
        }
    )
# target = tvm.target.Target("cuda", host="llvm")
target = _detect_local_cuda()

print(target)
# 定义计算任务
dev = tvm.cuda(0)

num_flop = 1228406784
W_np = np.random.uniform(size=(512, vocab_size)).astype("uint32")
S_np = np.random.uniform(size=(128, vocab_size)).astype("float16")
Input_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# Output_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
W_nd = tvm.nd.array(W_np, dev)
S_nd = tvm.nd.array(S_np, dev)
Input_nd = tvm.nd.array(Input_np, dev)
Output_nd = tvm.nd.array(np.zeros((1, 1, vocab_size), dtype="float32"), dev)
sch = tvm.tir.Schedule(ModuleSrc)
new_mod = sch.mod

# %%
# task = auto_scheduler.SearchTask(func=sch.mod['fused_fused_decode11_fused_matmul5_cast2'], args=sch.mod['fused_fused_decode11_fused_matmul5_cast2'].params, target=target)

# tune_option = auto_scheduler.TuningOptions(
#     num_measure_trials=10,
#     measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
#     verbose=2,
# )


database = ms.tune_tir(
    mod=new_mod,
    target=target,
    max_trials_global=64,
    num_trials_per_iter=64,
    work_dir="./tune_45593_1",
    cost_model="xgb"
)
print(len(database))
sch1 = ms.tir_integration.compile_tir(database, new_mod, target)
print(type(sch1))

# %%
# print(sch1.trace)
# print(sch1.mod.script())
rt_mod = tvm.build(sch1.mod, target="cuda")

evaluator = rt_mod.time_evaluator("main", dev, number=100)

print("evaluator GEMV-Blocking: %f GFLOPS" % (1228406784 / evaluator(W_nd, S_nd, Input_nd, Output_nd).mean / 1e9))

# %%
record_database = ms.Database.create(kind='json', work_dir='./tune_45593_1')

# %%
record_sch = ms.tir_integration.compile_tir(record_database, new_mod, target)

record_rt_mod = tvm.build(record_sch.mod, target="cuda")

record_evaluator = record_rt_mod.time_evaluator("main", dev, number=20)

print("evaluator GEMV-Blocking: %f GFLOPS" % (num_flop / record_evaluator(W_nd, S_nd, Input_nd, Output_nd).mean / 1e9))
print(record_sch.trace)
print(record_sch.mod.script())

# %%
from typing import TYPE_CHECKING, Dict, List, Optional, Union, Callable
from tvm import runtime
if TYPE_CHECKING:
    import numpy as np  # type: ignore
    from tvm.ir import IRModule
    from tvm.meta_schedule.runner import EvaluatorConfig, RPCConfig
    from tvm.runtime import Device, Module, NDArray
    from tvm.target import Target
    from tvm.runtime.vm import Executable


def f_measurement(
    rt_mod: runtime.Module, device: runtime.ndarray.Device, input_data: Dict[str, runtime.NDArray]
):
    vm = relax.VirtualMachine(rt_mod, device=device)
    vm.save_function("main", "measure_func", **input_data, include_return=False)
    evaluator = vm.time_evaluator(
        func_name="measure_func",
        dev=device,
        repeat=100,
        number=1,
        min_repeat_ms=500,
    )
    return evaluator()

def run_module_via_rpc(
    rpc_config: "RPCConfig",
    lib: Union["Module", "Executable"],
    dev_type: str,
    args: Union[Dict[int, "np.ndarray"], Dict[str, "np.ndarray"]],
    continuation: Callable,
    backend: Optional[str] = "graph",
):
    """Execute a tvm.runtime.Module on RPC remote"""
    # pylint: disable=import-outside-toplevel
    import os
    import tempfile

    from tvm.contrib.tar import tar
    from tvm.runtime import ndarray

    # pylint: enable=import-outside-toplevel

    with tempfile.TemporaryDirectory() as tmp_dir:
        # filename = os.path.join(tmp_dir, "tvm_tmp_mod." + tar.output_format)
        filename = os.path.join(tmp_dir, "tvm_tmp_mod." + "so")
        if backend == "vm":
            code, lib = lib.save(filename, fmt="so")
        from tvm.contrib import ndk
        lib.export_library(filename, ndk.create_shared)
        session = rpc_config.connect_server()
        print(type(session._sess))
        session.upload(filename)
        _, filename = os.path.split(filename)
        rt_mod = session.load_module(filename)
        
        if backend == "vm":
            rt_mod = session.get_function("runtime.Load_Executable")(code, rt_mod)
            # rt_mod = session.get_function("runtime.module.loadfile_relax.Executable")(filename)
        dev = session.device(dev_type=dev_type, dev_id=0)
        # print(dev)
        # create the remote runtime module
        print(rt_mod)
        print(rt_mod['main'])
        from tvm.contrib import graph_executor as runtime
        module = runtime.GraphModule(rt_mod["main"](dev))
        print(module)
        for k, v in args.items():
            module.set_input(k, tvm.nd.array(v))
        return module.run()
        # nd_args = {k: ndarray.array(v, dev) for k, v in args.items()}
        nd_args = {k: ndarray.empty(v.shape, v.dtype, dev) for k, v in args.items()}
        return continuation(rt_mod, dev, nd_args)
