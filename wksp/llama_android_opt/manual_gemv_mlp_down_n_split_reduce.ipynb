# %%
import os
import tvm
from tvm.script import ir as I
from tvm.script import tir as T
from tvm import autotvm, auto_scheduler
from tvm.autotvm.tuner import XGBTuner, GATuner, RandomTuner, GridSearchTuner
from tvm import meta_schedule as ms
from tvm.ir import IRModule
from tvm import relax
from tvm import rpc
from tvm.contrib import utils, ndk
x_shape = 11008
w_w_x = 1376
w_s_x = 344
w_y = 4096
func_name = "main"

@I.ir_module
class ModuleSrc:
    @T.prim_func(private=False)
    # fused_fused_decode5_fused_NT_matmul4_add
    def main(lv17: T.Buffer((T.int64(1376), T.int64(4096)), "uint32"), lv18: T.Buffer((T.int64(344), T.int64(4096)), "float16"), p_lv16: T.handle, p_lv12: T.handle, p_output0: T.handle):
        T.func_attr({"tir.noalias": T.bool(True)})
        n = T.int64()
        lv16 = T.match_buffer(p_lv16, (T.int64(1), n, T.int64(11008)), "float16")
        lv12 = T.match_buffer(p_lv12, (T.int64(1), n, T.int64(4096)), "float16")
        p_output0_intermediate = T.match_buffer(p_output0, (T.int64(1), n, T.int64(4096)), "float16")
        # with T.block("root"):
        decode = T.alloc_buffer((T.int64(11008), T.int64(4096)), "float16")
        p_output0_intermediate_1 = T.alloc_buffer((T.int64(4096), T.int64(11008)), "float16")
        var_NT_matmul_intermediate = T.alloc_buffer((T.int64(1), n, T.int64(4096)), "float16")
        for i, j in T.grid(T.int64(11008), T.int64(4096)):
            with T.block("decode"):
                v_i, v_j = T.axis.remap("SS", [i, j])
                T.reads(lv17[v_i // T.int64(8), v_j], lv18[v_i // T.int64(32), v_j])
                T.writes(decode[v_i, v_j])
                decode[v_i, v_j] = (T.Cast("float16", T.bitwise_and(T.shift_right(lv17[v_i // T.int64(8), v_j], T.Cast("uint32", v_i % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv18[v_i // T.int64(32), v_j]
        for ax0, ax1 in T.grid(T.int64(4096), T.int64(11008)):
            with T.block("T_transpose"):
                v_ax0, v_ax1 = T.axis.remap("SS", [ax0, ax1])
                T.reads(decode[v_ax1, v_ax0])
                T.writes(p_output0_intermediate_1[v_ax0, v_ax1])
                p_output0_intermediate_1[v_ax0, v_ax1] = decode[v_ax1, v_ax0]
        for i0, i1, i2, k in T.grid(T.int64(1), n, T.int64(4096), T.int64(11008)):
            with T.block("NT_matmul"):
                v_i0, v_i1, v_i2, v_k = T.axis.remap("SSSR", [i0, i1, i2, k])
                T.reads(lv16[v_i0, v_i1, v_k], p_output0_intermediate_1[v_i2, v_k])
                T.writes(var_NT_matmul_intermediate[v_i0, v_i1, v_i2])
                with T.init():
                    var_NT_matmul_intermediate[v_i0, v_i1, v_i2] = T.float16(0)
                var_NT_matmul_intermediate[v_i0, v_i1, v_i2] = var_NT_matmul_intermediate[v_i0, v_i1, v_i2] + lv16[v_i0, v_i1, v_k] * p_output0_intermediate_1[v_i2, v_k]
        for ax0, ax1, ax2 in T.grid(T.int64(1), n, T.int64(4096)):
            with T.block("T_add"):
                v_ax0, v_ax1, v_ax2 = T.axis.remap("SSS", [ax0, ax1, ax2])
                T.reads(lv12[v_ax0, v_ax1, v_ax2], var_NT_matmul_intermediate[v_ax0, v_ax1, v_ax2])
                T.writes(p_output0_intermediate[v_ax0, v_ax1, v_ax2])
                p_output0_intermediate[v_ax0, v_ax1, v_ax2] = lv12[v_ax0, v_ax1, v_ax2] + var_NT_matmul_intermediate[v_ax0, v_ax1, v_ax2]


rsplit_factor = 8
r_outter_loop = 344 // rsplit_factor
assert 344 % rsplit_factor == 0, "344 is not divisible by rsplit_factor"

@I.ir_module
class ModuleToManual:

###优化kernel配置####
# 参数:    vf   pr   bx  tx ty  tz
# kernel1 8	    4   32	16	8	8
# kernel2 4	    4	64	16	8
    @T.prim_func(private=False)
    #fused_decode2_fused_NT_matmul3_add_after
    def main(
        lv50: T.Buffer((T.int64(1376), T.int64(4096)), "uint32"),
        lv51: T.Buffer((T.int64(344), T.int64(4096)), "float16"),
        p_lv5: T.handle,
        p_lv3: T.handle,
        p_output0: T.handle,
    ):
        T.func_attr({"tir.noalias": T.bool(True), "tir.is_scheduled": 1})
        n = T.int64()
        lv5 = T.match_buffer(p_lv5, (T.int64(1), n, T.int64(11008)), "float16")
        lv3 = T.match_buffer(p_lv3, (T.int64(1), n, T.int64(4096)), "float16")
        p_output0_intermediate = T.match_buffer(
            p_output0, (T.int64(1), n, T.int64(4096)), "float16"
        )
        # with T.block("root"):
        decode_local = T.alloc_buffer(
            (T.int64(11008), T.int64(4096)), "float16", scope="local"
        )
        lv50_local = T.alloc_buffer((T.int64(1376), T.int64(4096)), "uint32", scope="local")
        lv51_local = T.alloc_buffer((T.int64(344), T.int64(4096)), "float16", scope="local")
        lv5_pad_local = T.alloc_buffer(
            (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(11008)),
            "float16",
            scope="local",
        )
        var_NT_matmul_intermediate_pad_local = T.alloc_buffer(
            (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(4096)),
            "float16",
            scope="local",
        )

        var_NT_matmul_intermediate_pad_rf = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16")
        var_NT_matmul_intermediate_pad_rf_local = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16", scope = "local")
        # 任务划分:
        ### 一个thread处理 `processed_rows_per_thread`行 `vectorize_factor` 列(输出角度)
        ### 完整处理 `processed_rows_per_thread` 行输入需要: blockIdx.x * threadIdx.x 配合
        ### 完整处理 `n` 行输入需要: blockIdx.y * threadIdx.y 配合
        #### 分析: 根据`n`变化的只有 blockIdx.y, 说明 blockIdx.x * threadIdx.x * threadIdx.y 可以完整处理32行输入
        #  4 16 24 128 2
        BlockIdx_x = 32#128
        # n = 32
        # BlockIdx_y = (n+31)//32 * 32 # 这里32是假设输入为32的倍数, //32的32 = thready * 
        ThreadIdx_x = 16#8
        ThreadIdx_y = 8#16
        vectorize_factor = 8#4
        # processed_columns_per_thread = vectorize_factor# w_y / (BlockIdx_x * ThreadIdx_x) == vectorize_factor
        processed_rows_per_thread = 4#2 == 32 / threadIdx.y
        ### reduce拆分
        ## 当前各个threadIndex的含义：
        #   blockIdx.y  : Bb = (n + 31) // 32 * 32, 一次kernel调用用于处理 Bb 个32行输入
        #   blockIdx.x  : 32, 和 threadIdx.x, vectorize_factor 配合, 一个线程用于处理 4096 个元素(一行)
        #                   (= blockIdx.x * threadIdx.x * vectorize_factor), 此外单线程还会同时处理 processed_rows_per_thread 行
        #   threadIdx.x : 16, 和 blockIdx.x, vectorize_factor 配合, 一个线程用于处理 4096 个元素(一行)
        #                   (= blockIdx.x * threadIdx.x * vectorize_factor), 此外单线程还会同时处理 processed_rows_per_thread 行
        #   threadIdx.y : 8, 和 processed_rows_per_thread 配合用于处理 1个 32行输入
        ## 加一个threadIdx.z, 来处理拆分reduce的情况
        #   当前一列11008拆分情况(参数固定, 其中4和8受限于group_size和weight bits不可修改, 仅可拆344): 344 * 4 * 8
        #   rsplit_factor: [8, 4, 2] -> outter_loop: [43, 86, 172]
        # rsplit_factor = 8
        # r_outter_loop = 344 // rsplit_factor
        # assert 344 % rsplit_factor == 0, "344 is not divisible by rsplit_factor"

        for i0_i1_fused_0_i0_i1_fused_1_0_fused in T.thread_binding(
            (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
        ):
            for i2_0 in T.thread_binding(T.int64(BlockIdx_x), thread="blockIdx.x"):
                for i0_i1_fused_1_1 in T.thread_binding(T.int64(ThreadIdx_y), thread="threadIdx.y"):
                    for i2_1 in T.thread_binding(T.int64(ThreadIdx_x), thread="threadIdx.x"):
                        for k_outter in T.thread_binding(T.int64(rsplit_factor), thread="threadIdx.z"):
                            for i0_i1_fused_1_2_init in range(T.int64(processed_rows_per_thread)):
                                for i2_2_init in T.vectorized(T.int64(vectorize_factor)):
                                    with T.block("NT_matmul_init"):
                                        vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                        v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                        v_i1 = T.axis.spatial(
                                            (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                            i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                            + i0_i1_fused_1_1 * processed_rows_per_thread
                                            + i0_i1_fused_1_2_init,
                                        )
                                        v_i2 = T.axis.spatial(
                                            T.int64(4096),
                                            i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + i2_2_init,
                                        )
                                        T.reads()
                                        T.writes(
                                            var_NT_matmul_intermediate_pad_rf_local[
                                                T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                            ]
                                        )
                                        var_NT_matmul_intermediate_pad_rf_local[
                                            T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                        ] = T.float16(0)
                            for k_0 in range(T.int64(r_outter_loop)):
                                for ax0 in range(T.int64(1)):
                                    for ax1 in T.vectorized(T.int64(vectorize_factor)):
                                        with T.block("lv51_local"):
                                            v0 = T.axis.spatial(T.int64(344), k_outter * r_outter_loop + k_0 + ax0)
                                            v1 = T.axis.spatial(
                                                T.int64(4096),
                                                i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax1,
                                            )
                                            T.reads(lv51[v0, v1])
                                            T.writes(lv51_local[v0, v1])
                                            lv51_local[v0, v1] = lv51[v0, v1]
                                for k_1 in range(T.int64(4)):
                                    for ax0 in range(T.int64(1)):
                                        for ax1 in T.vectorized(vectorize_factor):
                                            with T.block("lv50_local"):
                                                v0 = T.axis.spatial(
                                                    T.int64(1376), k_outter * r_outter_loop * T.int64(4) + k_0 * T.int64(4) + k_1 + ax0
                                                )
                                                v1 = T.axis.spatial(
                                                    T.int64(4096),
                                                    i2_0 * (ThreadIdx_x * vectorize_factor)
                                                    + i2_1 * vectorize_factor
                                                    + ax1,
                                                )
                                                T.reads(lv50[v0, v1])
                                                T.writes(lv50_local[v0, v1])
                                                lv50_local[v0, v1] = lv50[v0, v1]
                                    for k_2 in range(T.int64(8)):
                                        for ax0 in range(T.int64(1)):
                                            for ax1 in T.vectorized(vectorize_factor):
                                                with T.block("decode"):
                                                    v_i = T.axis.spatial(
                                                        T.int64(11008),
                                                        k_outter * r_outter_loop * T.int64(32)
                                                        + k_0 * T.int64(32)
                                                        + k_1 * T.int64(8)
                                                        + k_2
                                                        + ax0,
                                                    )
                                                    v_j = T.axis.spatial(
                                                        T.int64(4096),
                                                        i2_0 * (ThreadIdx_x * vectorize_factor)
                                                        + i2_1 * vectorize_factor
                                                        + ax1,
                                                    )
                                                    T.reads(
                                                        lv50_local[v_i // T.int64(8), v_j],
                                                        lv51_local[v_i // T.int64(32), v_j],
                                                    )
                                                    T.writes(decode_local[v_i, v_j])
                                                    decode_local[v_i, v_j] = (
                                                        T.Cast(
                                                            "float16",
                                                            T.bitwise_and(
                                                                T.shift_right(
                                                                    lv50_local[
                                                                        v_i // T.int64(8), v_j
                                                                    ],
                                                                    T.Cast(
                                                                        "uint32",
                                                                        v_i % T.int64(8),
                                                                    )
                                                                    * T.uint32(4),
                                                                ),
                                                                T.uint32(15),
                                                            ),
                                                        )
                                                        - T.float16(7)
                                                    ) * lv51_local[v_i // T.int64(32), v_j]
                                        for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                            for ax2 in T.vectorized(T.int64(1)):
                                                with T.block("lv5_pad_local"):
                                                    v0 = T.axis.spatial(T.int64(1), ax0)
                                                    v1 = T.axis.spatial(
                                                        (n + T.int64(31))
                                                        // T.int64(32)
                                                        * T.int64(32),
                                                        i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                        * T.int64(32)
                                                        + i0_i1_fused_1_1 * processed_rows_per_thread
                                                        + ax1,
                                                    )
                                                    v2 = T.axis.spatial(
                                                        T.int64(11008),
                                                        k_outter * r_outter_loop * T.int64(32)
                                                        + k_0 * T.int64(32)
                                                        + k_1 * T.int64(8)
                                                        + k_2
                                                        + ax2,
                                                    )
                                                    T.reads(lv5[v0, v1, v2])
                                                    T.writes(lv5_pad_local[v0, v1, v2])
                                                    lv5_pad_local[v0, v1, v2] = T.if_then_else(
                                                        v1 < n, lv5[v0, v1, v2], T.float16(0)
                                                    )
                                        for i0_i1_fused_1_2 in range(processed_rows_per_thread):
                                            for i2_2 in T.vectorized(vectorize_factor):
                                                with T.block("NT_matmul_update"):
                                                    vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                    v_i0 = T.axis.spatial(
                                                        T.int64(1), T.int64(0)
                                                    )
                                                    v_i1 = T.axis.spatial(
                                                        (n + T.int64(31))
                                                        // T.int64(32)
                                                        * T.int64(32),
                                                        i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                        * T.int64(32)
                                                        + i0_i1_fused_1_1 * processed_rows_per_thread
                                                        + i0_i1_fused_1_2,
                                                    )
                                                    v_i2 = T.axis.spatial(
                                                        T.int64(4096),
                                                        i2_0 * (ThreadIdx_x * vectorize_factor)
                                                        + i2_1 * vectorize_factor
                                                        + i2_2,
                                                    )
                                                    v_k = T.axis.reduce(
                                                        T.int64(11008),
                                                        k_outter * r_outter_loop * T.int64(32)
                                                        + k_0 * T.int64(32)
                                                        + k_1 * T.int64(8)
                                                        + k_2,
                                                    )
                                                    T.reads(
                                                        var_NT_matmul_intermediate_pad_rf_local[
                                                            T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                        ],
                                                        lv5_pad_local[v_i0, v_i1, v_k],
                                                        decode_local[v_k, v_i2],
                                                    )
                                                    T.writes(
                                                        var_NT_matmul_intermediate_pad_rf_local[
                                                            T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                        ]
                                                    )
                                                    var_NT_matmul_intermediate_pad_rf_local[
                                                        T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                    ] = (
                                                        var_NT_matmul_intermediate_pad_rf_local[
                                                            T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                        ]
                                                        + lv5_pad_local[v_i0, v_i1, v_k]
                                                        * decode_local[v_k, v_i2]
                                                    )
                            for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                for ax2 in T.vectorized(vectorize_factor):
                                    with T.block("var_NT_matmul_intermediate_pad_local"):
                                        vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                        v0 = T.axis.spatial(T.int64(1), ax0)
                                        v1 = T.axis.spatial(
                                            (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                            i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                            + i0_i1_fused_1_1 * processed_rows_per_thread
                                            + ax1,
                                        )
                                        v2 = T.axis.spatial(
                                            T.int64(4096),
                                            i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax2,
                                        )
                                        T.reads(
                                            lv3[v0, v1, v2],
                                            var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2],
                                        )
                                        T.writes(var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2])
                                        if v1 < n:
                                            var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2] = (
                                                var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2]
                                                )
        ## sum(sub_reduce), sub_reduce shape: [rfactor, 1, n, 4096]
        ### reuduce axis: rfactor
        ### spatial axes: [1, n, 4096]
        #### threadIndex 划分:
        ## blockIdx.y: 处理by个32行数据
        ## blockIdx.x: 和tx及vfactor配合, 处理4096个columns数据, 也可能处理多行(rows_per_thread)
        ## threadIdx.x: ref to blockIdx.x
        ## threadIdx.y: 与rows_per_thread配合处理32行数据
        REDUCE_BX = 64#16
        REDUCE_TX = 16#32
        REDUCE_TY = 8#16
        REDUCE_VFACTOR = 4#8
        REDUCE_ROWS_PER_THREAD = 32 // REDUCE_TY
        for sp_row_by in T.thread_binding(
            (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
        ):
            for sp_col_bx in T.thread_binding(T.int64(REDUCE_BX), thread="blockIdx.x"):
                for sp_col_tx in T.thread_binding(T.int64(REDUCE_TX), thread="threadIdx.x"):
                    for sp_row_ty in T.thread_binding(T.int64(REDUCE_TY), thread="threadIdx.y"):
                        for ax0, ax1 in T.grid(T.int64(1), REDUCE_ROWS_PER_THREAD):
                            for sp_col_vfactor in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                for k_0_0 in range(T.int64(rsplit_factor)):
                                    with T.block("matmul_update"):
                                        vk_0_0 = T.axis.reduce(T.int64(rsplit_factor), k_0_0)
                                        v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                        v_i1 = T.axis.spatial((n + T.int64(31))
                                                        // T.int64(32)
                                                        * T.int64(32),
                                                        sp_row_by * T.int64(32)
                                                        + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                        + ax1)
                                        v_i2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + sp_col_vfactor)
                                        T.reads(var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2])
                                        T.writes(var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2])
                                        with T.init():
                                            var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = T.float16(0)
                                        var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] + var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2]
                        for ax0, ax1 in T.grid(T.int64(1), T.int64(REDUCE_ROWS_PER_THREAD)):
                            for ax2 in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                with T.block("output"):
                                    v0 = T.axis.spatial(T.int64(1), T.int64(0))
                                    v1 = T.axis.spatial((n + T.int64(31))
                                                    // T.int64(32)
                                                    * T.int64(32),
                                                    sp_row_by * T.int64(32)
                                                    + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                    + ax1)
                                    v2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + ax2)
                                    T.reads(lv3[v0, v1, v2], p_output0_intermediate[v0, v1, v2])
                                    T.writes(p_output0_intermediate[v0, v1, v2])
                                    if v1 < n:
                                        p_output0_intermediate[v0, v1, v2] = (lv3[v0, v1, v2]
                                                            + var_NT_matmul_intermediate_pad_local[v0, v1, v2])

sch_manual = tvm.tir.Schedule(ModuleToManual)
print(sch_manual.mod.script())
print("================================================")
rt_mod = tvm.build(sch_manual.mod, target="opencl")
print(rt_mod.imported_modules[0].get_source())
# Out:
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(lv50: T.Buffer((T.int64(1376), T.int64(4096)), "uint32"), lv51: T.Buffer((T.int64(344), T.int64(4096)), "float16"), p_lv5: T.handle, p_lv3: T.handle, p_output0: T.handle):
#         T.func_attr({"tir.is_scheduled": 1, "tir.noalias": T.bool(True)})
#         n = T.int64()
#         lv5 = T.match_buffer(p_lv5, (T.int64(1), n, T.int64(11008)), "float16")
#         lv3 = T.match_buffer(p_lv3, (T.int64(1), n, T.int64(4096)), "float16")
#         p_output0_intermediate = T.match_buffer(p_output0, (T.int64(1), n, T.int64(4096)), "float16")
#         # with T.block("root"):
#         decode_local = T.alloc_buffer((T.int64(11008), T.int64(4096)), "float16", scope="local")
#         lv50_local = T.alloc_buffer((T.int64(1376), T.int64(4096)), "uint32", scope="local")
#         lv51_local = T.alloc_buffer((T.int64(344), T.int64(4096)), "float16", scope="local")
#         lv5_pad_local = T.alloc_buffer((T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(11008)), "float16", scope="local")
#         var_NT_matmul_intermediate_pad_local = T.alloc_buffer((T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(4096)), "float16", scope="local")
#         var_NT_matmul_intermediate_pad_rf = T.alloc_buffer((8, 1, (n + T.int64(31)) // T.int64(32) * T.int64(32), 4096), "float16")
#         var_NT_matmul_intermediate_pad_rf_local = T.alloc_buffer((8, 1, (n + T.int64(31)) // T.int64(32) * T.int64(32), 4096), "float16", scope="local")
#         BlockIdx_x: T.int32 = 32
#         ThreadIdx_x: T.int32 = 16
#         ThreadIdx_y: T.int32 = 8
#         vectorize_factor: T.int32 = 8
#         processed_rows_per_thread: T.int32 = 4
#         for i0_i1_fused_0_i0_i1_fused_1_0_fused in T.thread_binding((n + T.int64(31)) // T.int64(32), thread="blockIdx.y"):
#             for i2_0 in T.thread_binding(T.Cast("int64", BlockIdx_x), thread="blockIdx.x"):
#                 for i0_i1_fused_1_1 in T.thread_binding(T.Cast("int64", ThreadIdx_y), thread="threadIdx.y"):
#                     for i2_1 in T.thread_binding(T.Cast("int64", ThreadIdx_x), thread="threadIdx.x"):
#                         for k_outter in T.thread_binding(T.int64(8), thread="threadIdx.z"):
#                             for i0_i1_fused_1_2_init in range(T.Cast("int64", processed_rows_per_thread)):
#                                 for i2_2_init in T.vectorized(T.Cast("int64", vectorize_factor)):
#                                     with T.block("NT_matmul_init"):
#                                         vk_outter_0 = T.axis.spatial(T.int64(8), k_outter)
#                                         v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
#                                         v_i1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32) + i0_i1_fused_1_1 * T.Cast("int64", processed_rows_per_thread) + i0_i1_fused_1_2_init)
#                                         v_i2 = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + i2_2_init)
#                                         T.reads()
#                                         T.writes(var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2])
#                                         var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2] = T.float16(0)
#                             for k_0 in range(T.int64(43)):
#                                 for ax0 in range(T.int64(1)):
#                                     for ax1 in T.vectorized(T.Cast("int64", vectorize_factor)):
#                                         with T.block("lv51_local"):
#                                             v0 = T.axis.spatial(T.int64(344), k_outter * T.int64(43) + k_0 + ax0)
#                                             v1 = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + ax1)
#                                             T.reads(lv51[v0, v1])
#                                             T.writes(lv51_local[v0, v1])
#                                             lv51_local[v0, v1] = lv51[v0, v1]
#                                 for k_1 in range(T.int64(4)):
#                                     for ax0 in range(T.int64(1)):
#                                         for ax1 in T.vectorized(vectorize_factor):
#                                             with T.block("lv50_local"):
#                                                 v0 = T.axis.spatial(T.int64(1376), k_outter * T.int64(43) * T.int64(4) + k_0 * T.int64(4) + k_1 + ax0)
#                                                 v1 = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + T.Cast("int64", ax1))
#                                                 T.reads(lv50[v0, v1])
#                                                 T.writes(lv50_local[v0, v1])
#                                                 lv50_local[v0, v1] = lv50[v0, v1]
#                                     for k_2 in range(T.int64(8)):
#                                         for ax0 in range(T.int64(1)):
#                                             for ax1 in T.vectorized(vectorize_factor):
#                                                 with T.block("decode"):
#                                                     v_i = T.axis.spatial(T.int64(11008), k_outter * T.int64(43) * T.int64(32) + k_0 * T.int64(32) + k_1 * T.int64(8) + k_2 + ax0)
#                                                     v_j = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + T.Cast("int64", ax1))
#                                                     T.reads(lv50_local[v_i // T.int64(8), v_j], lv51_local[v_i // T.int64(32), v_j])
#                                                     T.writes(decode_local[v_i, v_j])
#                                                     decode_local[v_i, v_j] = (T.Cast("float16", T.bitwise_and(T.shift_right(lv50_local[v_i // T.int64(8), v_j], T.Cast("uint32", v_i % T.int64(8)) * T.uint32(4)), T.uint32(15))) - T.float16(7)) * lv51_local[v_i // T.int64(32), v_j]
#                                         for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
#                                             for ax2 in T.vectorized(T.int64(1)):
#                                                 with T.block("lv5_pad_local"):
#                                                     v0 = T.axis.spatial(T.int64(1), ax0)
#                                                     v1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32) + i0_i1_fused_1_1 * T.Cast("int64", processed_rows_per_thread) + T.Cast("int64", ax1))
#                                                     v2 = T.axis.spatial(T.int64(11008), k_outter * T.int64(43) * T.int64(32) + k_0 * T.int64(32) + k_1 * T.int64(8) + k_2 + ax2)
#                                                     T.reads(lv5[v0, v1, v2])
#                                                     T.writes(lv5_pad_local[v0, v1, v2])
#                                                     lv5_pad_local[v0, v1, v2] = T.if_then_else(v1 < n, lv5[v0, v1, v2], T.float16(0))
#                                         for i0_i1_fused_1_2 in range(processed_rows_per_thread):
#                                             for i2_2 in T.vectorized(vectorize_factor):
#                                                 with T.block("NT_matmul_update"):
#                                                     vk_outter_0 = T.axis.spatial(T.int64(8), k_outter)
#                                                     v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
#                                                     v_i1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32) + i0_i1_fused_1_1 * T.Cast("int64", processed_rows_per_thread) + T.Cast("int64", i0_i1_fused_1_2))
#                                                     v_i2 = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + T.Cast("int64", i2_2))
#                                                     v_k = T.axis.reduce(T.int64(11008), k_outter * T.int64(43) * T.int64(32) + k_0 * T.int64(32) + k_1 * T.int64(8) + k_2)
#                                                     T.reads(var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2], lv5_pad_local[v_i0, v_i1, v_k], decode_local[v_k, v_i2])
#                                                     T.writes(var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2])
#                                                     var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2] = var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v_i0, v_i1, v_i2] + lv5_pad_local[v_i0, v_i1, v_k] * decode_local[v_k, v_i2]
#                             for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
#                                 for ax2 in T.vectorized(vectorize_factor):
#                                     with T.block("var_NT_matmul_intermediate_pad_local"):
#                                         vk_outter_0, v0 = T.axis.remap("SS", [k_outter, ax0])
#                                         v1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32) + i0_i1_fused_1_1 * T.Cast("int64", processed_rows_per_thread) + T.Cast("int64", ax1))
#                                         v2 = T.axis.spatial(T.int64(4096), i2_0 * T.Cast("int64", ThreadIdx_x * vectorize_factor) + i2_1 * T.Cast("int64", vectorize_factor) + T.Cast("int64", ax2))
#                                         T.reads(lv3[v0, v1, v2], var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v0, v1, v2])
#                                         T.writes(var_NT_matmul_intermediate_pad_rf[vk_outter_0, v0, v1, v2])
#                                         if v1 < n:
#                                             var_NT_matmul_intermediate_pad_rf[vk_outter_0, v0, v1, v2] = var_NT_matmul_intermediate_pad_rf_local[vk_outter_0, v0, v1, v2]
#         REDUCE_BX: T.int32 = 64
#         REDUCE_TX: T.int32 = 16
#         REDUCE_TY: T.int32 = 8
#         REDUCE_VFACTOR: T.int32 = 4
#         REDUCE_ROWS_PER_THREAD: T.int32 = 32 // REDUCE_TY
#         for sp_row_by in T.thread_binding((n + T.int64(31)) // T.int64(32), thread="blockIdx.y"):
#             for sp_col_bx in T.thread_binding(T.Cast("int64", REDUCE_BX), thread="blockIdx.x"):
#                 for sp_col_tx in T.thread_binding(T.Cast("int64", REDUCE_TX), thread="threadIdx.x"):
#                     for sp_row_ty in T.thread_binding(T.Cast("int64", REDUCE_TY), thread="threadIdx.y"):
#                         for ax0, ax1 in T.grid(T.int64(1), REDUCE_ROWS_PER_THREAD):
#                             for sp_col_vfactor in T.vectorized(T.Cast("int64", REDUCE_VFACTOR)):
#                                 for k_0_0 in range(T.int64(8)):
#                                     with T.block("matmul_update"):
#                                         vk_0_0 = T.axis.reduce(T.int64(8), k_0_0)
#                                         v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
#                                         v_i1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), sp_row_by * T.int64(32) + sp_row_ty * T.Cast("int64", REDUCE_ROWS_PER_THREAD) + T.Cast("int64", ax1))
#                                         v_i2 = T.axis.spatial(T.int64(4096), sp_col_bx * T.Cast("int64", REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * T.Cast("int64", REDUCE_VFACTOR) + sp_col_vfactor)
#                                         T.reads(var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2])
#                                         T.writes(var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2])
#                                         with T.init():
#                                             var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = T.float16(0)
#                                         var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] + var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2]
#                         for ax0, ax1 in T.grid(T.int64(1), T.Cast("int64", REDUCE_ROWS_PER_THREAD)):
#                             for ax2 in T.vectorized(T.Cast("int64", REDUCE_VFACTOR)):
#                                 with T.block("output"):
#                                     v0 = T.axis.spatial(T.int64(1), T.int64(0))
#                                     v1 = T.axis.spatial((n + T.int64(31)) // T.int64(32) * T.int64(32), sp_row_by * T.int64(32) + sp_row_ty * T.Cast("int64", REDUCE_ROWS_PER_THREAD) + ax1)
#                                     v2 = T.axis.spatial(T.int64(4096), sp_col_bx * T.Cast("int64", REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * T.Cast("int64", REDUCE_VFACTOR) + ax2)
#                                     T.reads(lv3[v0, v1, v2], p_output0_intermediate[v0, v1, v2])
#                                     T.writes(p_output0_intermediate[v0, v1, v2])
#                                     if v1 < n:
#                                         p_output0_intermediate[v0, v1, v2] = lv3[v0, v1, v2] + var_NT_matmul_intermediate_pad_local[v0, v1, v2]
# ================================================
# // Function: main_kernel_1
# #ifdef cl_khr_fp16
# #pragma OPENCL EXTENSION cl_khr_fp16 : enable
# #elif defined(cl_amd_fp16)
# #pragma OPENCL EXTENSION cl_amd_fp16 : enable
# #else
# #error "Half precision floating point not supported by OpenCL implementation on your device."
# #endif
#
# __kernel void main_kernel_1(__global half* restrict lv3, __global half* restrict p_output0_intermediate, __global half* restrict var_NT_matmul_intermediate_pad_rf, long n) {
#   half4 var_NT_matmul_intermediate_pad_local[4];
#   for (int ax1 = 0; ax1 < 4; ++ax1) {
#     for (long k_0_0 = 0; k_0_0 < (long)8; ++k_0_0) {
#       if (k_0_0 == (long)0) {
#         var_NT_matmul_intermediate_pad_local[(convert_long(ax1))] = ((half4)((half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f));
#       }
#       var_NT_matmul_intermediate_pad_local[(convert_long(ax1))] = (var_NT_matmul_intermediate_pad_local[(convert_long(ax1))] + vload4(0, var_NT_matmul_intermediate_pad_rf + (((((((convert_long(get_group_id(1))) * (long)131072) + ((k_0_0 * ((n + (long)31) >> (long)5)) * (long)131072)) + ((convert_long(get_local_id(1))) * (long)16384)) + ((convert_long(ax1)) * (long)4096)) + ((convert_long(get_group_id(0))) * (long)64)) + ((convert_long(get_local_id(0))) * (long)4))));
#     }
#   }
#   for (long ax1_1 = 0; ax1_1 < (long)4; ++ax1_1) {
#     if (((((convert_long(get_group_id(1))) * (long)32) + ((convert_long(get_local_id(1))) * (long)4)) + ax1_1) < n) {
#       vstore4((vload4(0, lv3 + ((((((convert_long(get_group_id(1))) * (long)131072) + ((convert_long(get_local_id(1))) * (long)16384)) + (ax1_1 * (long)4096)) + ((convert_long(get_group_id(0))) * (long)64)) + ((convert_long(get_local_id(0))) * (long)4))) + var_NT_matmul_intermediate_pad_local[ax1_1]), 0, p_output0_intermediate + ((((((convert_long(get_group_id(1))) * (long)131072) + ((convert_long(get_local_id(1))) * (long)16384)) + (ax1_1 * (long)4096)) + ((convert_long(get_group_id(0))) * (long)64)) + ((convert_long(get_local_id(0))) * (long)4)));
#     }
#   }
# }
#
# // Function: main_kernel
# #ifdef cl_khr_fp16
# #pragma OPENCL EXTENSION cl_khr_fp16 : enable
# #elif defined(cl_amd_fp16)
# #pragma OPENCL EXTENSION cl_amd_fp16 : enable
# #else
# #error "Half precision floating point not supported by OpenCL implementation on your device."
# #endif
#
# __kernel void main_kernel(__global half* restrict lv5, __global uint* restrict lv50, __global half* restrict lv51, __global half* restrict var_NT_matmul_intermediate_pad_rf, long n) {
#   half8 var_NT_matmul_intermediate_pad_rf_local[4];
#   half8 lv51_local[1];
#   uint8 lv50_local[1];
#   half8 decode_local[1];
#   half lv5_pad_local[4];
#   for (int i0_i1_fused_1_2_init = 0; i0_i1_fused_1_2_init < 4; ++i0_i1_fused_1_2_init) {
#     var_NT_matmul_intermediate_pad_rf_local[i0_i1_fused_1_2_init] = ((half8)((half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f, (half)0.000000e+00f));
#   }
#   for (long k_0 = 0; k_0 < (long)43; ++k_0) {
#     lv51_local[0] = vload8(0, lv51 + (((((convert_long(get_local_id(2))) * (long)176128) + (k_0 * (long)4096)) + ((convert_long(get_group_id(0))) * (long)128)) + ((convert_long(get_local_id(0))) * (long)8)));
#     for (long k_1 = 0; k_1 < (long)4; ++k_1) {
#       lv50_local[0] = vload8(0, lv50 + ((((((convert_long(get_local_id(2))) * (long)704512) + (k_0 * (long)16384)) + (k_1 * (long)4096)) + ((convert_long(get_group_id(0))) * (long)128)) + ((convert_long(get_local_id(0))) * (long)8)));
#       for (long k_2 = 0; k_2 < (long)8; ++k_2) {
#         decode_local[0] = (((convert_half8(((lv50_local[0]  >>  ((uint8)(((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4), ((convert_uint(k_2)) * (uint)4))))  &  ((uint8)((uint)15, (uint)15, (uint)15, (uint)15, (uint)15, (uint)15, (uint)15, (uint)15))))) - ((half8)((half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f, (half)7.000000e+00f))) * lv51_local[0]);
#         for (int ax1 = 0; ax1 < 4; ++ax1) {
#           lv5_pad_local[ax1] = ((((((convert_long(get_group_id(1))) * (long)32) + ((convert_long(get_local_id(1))) * (long)4)) + (convert_long(ax1))) < n) ? lv5[((((((((convert_long(get_group_id(1))) * (long)352256) + ((convert_long(get_local_id(1))) * (long)44032)) + ((convert_long(ax1)) * (long)11008)) + ((convert_long(get_local_id(2))) * (long)1376)) + (k_0 * (long)32)) + (k_1 * (long)8)) + k_2)] : (half)0.000000e+00f);
#         }
#         for (int i0_i1_fused_1_2 = 0; i0_i1_fused_1_2 < 4; ++i0_i1_fused_1_2) {
#           var_NT_matmul_intermediate_pad_rf_local[i0_i1_fused_1_2] = (var_NT_matmul_intermediate_pad_rf_local[i0_i1_fused_1_2] + (((half8)(lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2], lv5_pad_local[i0_i1_fused_1_2])) * decode_local[0]));
#         }
#       }
#     }
#   }
#   for (int ax1_1 = 0; ax1_1 < 4; ++ax1_1) {
#     if (((((convert_long(get_group_id(1))) * (long)32) + ((convert_long(get_local_id(1))) * (long)4)) + (convert_long(ax1_1))) < n) {
#       vstore8(var_NT_matmul_intermediate_pad_rf_local[ax1_1], 0, var_NT_matmul_intermediate_pad_rf + (((((((convert_long(get_group_id(1))) * (long)131072) + (((convert_long(get_local_id(2))) * ((n + (long)31) >> (long)5)) * (long)131072)) + ((convert_long(get_local_id(1))) * (long)16384)) + ((convert_long(ax1_1)) * (long)4096)) + ((convert_long(get_group_id(0))) * (long)128)) + ((convert_long(get_local_id(0))) * (long)8)));
#     }
#   }
# }

# %%
# run and compare with cuda
import numpy as np
def _detect_local_cuda():
    dev = tvm.cuda()
    if not dev.exist:
        return None
    return tvm.target.Target(
        {
            "kind": "cuda",
            "max_shared_memory_per_block": dev.max_shared_memory_per_block,
            "max_threads_per_block": dev.max_threads_per_block,
            "thread_warp_size": dev.warp_size,
            "registers_per_block": 65536,
            "arch": "sm_" + tvm.cuda().compute_version.replace(".", ""),
        }
    )
# target = tvm.target.Target("cuda", host="llvm")
target = _detect_local_cuda()

print(target)
# 定义计算任务
dev = tvm.cuda(0)

num_flop = 1228406784
seq_len = 32
W_w_np = np.random.uniform(size=(w_w_x, w_y)).astype("uint32")
W_s_np = np.random.uniform(size=(w_s_x, w_y)).astype("float16")
Input_np = np.random.uniform(size=(1, seq_len, x_shape)).astype("float16")
Add_np = np.random.uniform(size=(1, seq_len, w_y)).astype("float16")
# W_w_np = np.ones((w_w_x, w_y), np.uint32) * 1#.astype("uint32")
# W_s_np = np.ones((w_s_x, w_y), np.float16) * 1#.astype("float16") * 2
# Input_np = np.ones((1, 1, x_shape), np.float16)#.astype("float16")
Output_nd = tvm.nd.array(np.zeros((1, seq_len, w_y), dtype="float16"), dev)
def numpy_caculate():
    test_cols = 10
    test_rows = 2
    reduce_div_factor = 8
    per_reduce_div_shape = x_shape//reduce_div_factor
    output = np.zeros((1, test_rows, test_cols), dtype = np.float16)
    output_rf = np.zeros((reduce_div_factor, 1, test_rows, test_cols), dtype = np.float16)
    W_w_inv_np = np.transpose(W_w_np)
    W_s_inv_np = np.transpose(W_s_np)
    for row in range(test_rows):
        for i in range(test_cols):
            for rf in range(reduce_div_factor):
                for r in range(per_reduce_div_shape * rf, per_reduce_div_shape * (rf+1)):
                    temp = Input_np[0][row][r] * np.float16((W_w_inv_np[i][r // 8] >> ((r % 8) * 4) & (15)) - np.float16(7.0)) * W_s_inv_np[i][r // 32]
                    output_rf[rf][0][row][i] = output_rf[rf][0][row][i] + temp
                output[0][row][i] = output[0][row][i] + output_rf[rf][0][row][i]
            output[0][row][i] = output[0][row][i] + Add_np[0][row][i]
    print(output)

    output = np.zeros((1, test_rows, test_cols), dtype = np.float16)
    output_rf = np.zeros((reduce_div_factor, 1, test_rows, test_cols), dtype = np.float16)
    for row in range(test_rows):
        for i in range(test_cols):
            for rf in range(reduce_div_factor):
                for r in range(per_reduce_div_shape * rf, per_reduce_div_shape * (rf+1)):
                    temp = Input_np[0][row][r] * np.float16((W_w_np[r // 8][i] >> ((r % 8) * 4) & (15)) - np.float16(7.0)) * W_s_np[r // 32][i]
                    output_rf[rf][0][row][i] = output_rf[rf][0][row][i] + temp
                output[0][row][i] = output[0][row][i] + output_rf[rf][0][row][i]
            output[0][row][i] = output[0][row][i] + Add_np[0][row][i]
    print(output)
numpy_caculate()
def print_npdata(np_data: np.ndarray) :
    print(np_data)
    print_num = 20
    d = np_data.flatten()
    p_size = print_num if d.size > print_num else d.size
    print(d[:p_size])
# Out:
# cuda -keys=cuda,gpu -arch=sm_61 -max_num_threads=1024 -max_shared_memory_per_block=49152 -max_threads_per_block=1024 -registers_per_block=65536 -thread_warp_size=32
# [[[-19952. -18368. -17648. -19808. -19440. -19024. -18912. -18496.
#    -19984. -19440.]
#   [-19600. -18336. -17504. -19712. -19296. -18992. -18880. -18448.
#    -19968. -19264.]]]
# [[[-19952. -18368. -17648. -19808. -19440. -19024. -18912. -18496.
#    -19984. -19440.]
#   [-19600. -18336. -17504. -19712. -19296. -18992. -18880. -18448.
#    -19968. -19264.]]]

# %%
# cuda未优化版本测试
sch = tvm.tir.Schedule(ModuleSrc)
with target:
    src_gpu_mod = tvm.tir.transform.DefaultGPUSchedule()(sch.mod) ##
rt_mod = tvm.build(src_gpu_mod, target="cuda")
W_w_nd = tvm.nd.array(W_w_np, dev)
W_s_nd = tvm.nd.array(W_s_np, dev)
Input_nd = tvm.nd.array(Input_np, dev)
Add_nd = tvm.nd.array(Add_np, dev)
Output_nd = tvm.nd.array(np.zeros((1, seq_len, w_y), dtype="float16"), dev)
evaluator = rt_mod.time_evaluator("main", dev, number=100)
print("manual_evaluator GEMV-Blocking: %f GFLOPS" % (num_flop / evaluator(W_w_nd, W_s_nd, Input_nd, Add_nd, Output_nd).mean / 1e9))
# print(Output_nd.numpy())
print_npdata(Output_nd.numpy())
# Out:
# manual_evaluator GEMV-Blocking: 1.541656 GFLOPS
# [[[-13704. -13152. -13264. ... -12968. -12312. -13288.]
#   [-13720. -13192. -13448. ... -13112. -12416. -13640.]
#   [-13576. -13032. -13376. ... -13136. -12424. -13384.]
#   ...
#   [-13520. -13096. -13384. ... -12880. -12552. -13552.]
#   [-13800. -13144. -13328. ... -12864. -12464. -13640.]
#   [-13664. -13232. -13360. ... -12952. -12376. -13360.]]]
# [-13704. -13152. -13264. -13504. -13016. -13128. -12216. -13544. -13600.
#  -13192. -13160. -12784. -13136. -13392. -13624. -13736. -12800. -11776.
#  -12904. -12656.]

# %%
# cuda优化版本测试
sch = tvm.tir.Schedule(ModuleToManual)
rt_mod = tvm.build(sch.mod, target="cuda")
W_w_nd = tvm.nd.array(W_w_np, dev)
W_s_nd = tvm.nd.array(W_s_np, dev)
Input_nd = tvm.nd.array(Input_np, dev)
Add_nd = tvm.nd.array(Add_np, dev)
Output_nd = tvm.nd.array(np.zeros((1, seq_len, w_y), dtype="float16"), dev)
evaluator = rt_mod.time_evaluator("main", dev, number=100)
print("manual_evaluator GEMV-Blocking: %f GFLOPS" % (num_flop / evaluator(W_w_nd, W_s_nd, Input_nd, Add_nd, Output_nd).mean / 1e9))
# print(Output_nd.numpy())
print_npdata(Output_nd.numpy())
# Out:
# manual_evaluator GEMV-Blocking: 14.064085 GFLOPS
# [[[-18816. -18800. -18592. ... -18976. -18832. -18752.]
#   [-19088. -19040. -18928. ... -19216. -19024. -18848.]
#   [-19168. -18976. -18960. ... -19328. -19152. -18896.]
#   ...
#   [-19232. -18912. -18912. ... -19328. -19200. -18944.]
#   [-19040. -18944. -18944. ... -19376. -18976. -18992.]
#   [-18928. -18784. -18752. ... -19136. -18944. -18848.]]]
# [-18816. -18800. -18592. -19344. -19376. -17488. -19440. -18080. -18368.
#  -18816. -17824. -17552. -18848. -18832. -20384. -18304. -18752. -19168.
#  -18272. -18352.]

# %%
os.environ["TVM_NDK_CC"]="/home/sensetime/Android/Sdk/ndk/25.2.9519653/toolchains/llvm/prebuilt/linux-x86_64/bin/aarch64-linux-android33-clang++"
target = tvm.target.Target("opencl -device=adreno", host="llvm -mtriple=aarch64-linux-gnu")
device_key="android"
rpc_host = "10.4.236.32"
rpc_port = 9190
comp_target = tvm.target.Target("opencl", host="llvm -mtriple=aarch64-linux-android")  # TODO: Only support arm64 for now

def test_opencl(mod: tvm.IRModule, name_hint: str):
    # mod = tvm.lower(sch_manual.mod)
    print("Build ...")
    android_rt_mod = tvm.build(mod, target="opencl", target_host="llvm -mtriple=aarch64-linux-android")
    # print(android_rt_mod.imported_modules[0].get_source())
    temp = utils.tempdir()
    path_dso_cl = temp.relpath("dev_lib_cl.so")
    android_rt_mod.export_library(path_dso_cl, ndk.create_shared)

    print("Run GPU(OpenCL Flavor) test ...")
    # Establish remote connection with target hardware

    tracker = rpc.connect_tracker(rpc_host, rpc_port)
    remote = tracker.request(device_key, priority=0, session_timeout=60)
    print("Connect to device done.")
    dev = remote.cl(0)
    remote.upload(path_dso_cl)
    f1 = remote.load_module("dev_lib_cl.so")

    W_w_nd = tvm.nd.array(W_w_np, dev)
    W_s_nd = tvm.nd.array(W_s_np, dev)
    Input_nd = tvm.nd.array(Input_np, dev)
    Add_nd = tvm.nd.array(Add_np, dev)
    Output_nd = tvm.nd.array(np.zeros((1, seq_len, w_y), dtype="float16"), dev)
    test_number=32
    time_f = f1.time_evaluator(f1.entry_name, dev, number=test_number)
    cost = time_f(W_w_nd, W_s_nd, Input_nd, Add_nd, Output_nd).mean
    print("evaluator[%s] GEMV-Blocking: %fms with loop %d" % (name_hint, cost * 1000, test_number))
    print("evaluator[%s] GEMV-Blocking: %fGFLOPS" % (name_hint, num_flop / cost / 1e9))

    print_npdata(Output_nd.numpy())
    # return Output_nd.numpy()
    return cost*1000 # unit: ms

# %%
# 未优化版本opencl测试
from tvm import dlight as dl
sch = tvm.tir.Schedule(ModuleSrc)
with target:
    # src_gpu_mod = tvm.tir.transform.DefaultGPUSchedule()(sch.mod) ##
    mod_deploy = dl.ApplyDefaultSchedule(  # pylint: disable=not-callable
        dl.gpu.Matmul(),
        dl.gpu.GEMV(),
        dl.gpu.Reduction(),
        dl.gpu.GeneralReduction(),
        dl.gpu.Fallback(),
    )(sch.mod)
src_output = test_opencl(mod_deploy, "source")
# print_npdata(src_output)
# Out:
# Build ...
# /data/workspace/llm/github/new_wksp/tvm-unity/python/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[source] GEMV-Blocking: 192.772656ms with loop 32
# evaluator[source] GEMV-Blocking: 6.372308GFLOPS
# [[[-12592. -12432. -12504. ... -12576. -13104. -13408.]
#   [-12544. -12744. -12864. ... -12864. -12808. -13312.]
#   [-12856. -12800. -13136. ... -12912. -13464. -13376.]
#   ...
#   [-12904. -12680. -12792. ... -12984. -13192. -13392.]
#   [-12992. -12712. -13096. ... -13312. -13224. -13600.]
#   [-12568. -12456. -12640. ... -13032. -13152. -13584.]]]
# [-12592. -12432. -12504. -13744. -13992. -11800. -13272. -12384. -12984.
#  -13408. -12608. -11736. -13048. -12776. -14720. -12496. -12616. -13288.
#  -12680. -13264.]

# %%
#优化版本opencl测试
# print(sch_manual.mod)
opt_output = test_opencl(sch_manual.mod, "opted")
# print_npdata(opt_output)
# np.testing.assert_equal(opt_output, src_output)
# Out:
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[opted] GEMV-Blocking: 6.539576ms with loop 32
# evaluator[opted] GEMV-Blocking: 187.841962GFLOPS
# [[[-19936. -18368. -17648. ... -19520. -18288. -19296.]
#   [-19600. -18336. -17504. ... -19456. -18400. -19200.]
#   [-19904. -18496. -17616. ... -19616. -18432. -19440.]
#   ...
#   [-19760. -18416. -17600. ... -19344. -18176. -19312.]
#   [-19824. -18624. -17744. ... -19632. -18576. -19456.]
#   [-19552. -18128. -17488. ... -19280. -18304. -19168.]]]
# [-19936. -18368. -17648. -19808. -19440. -19024. -18912. -18496. -19984.
#  -19440. -18704. -19152. -18112. -19504. -19024. -18848. -19488. -18160.
#  -18800. -18704.]

# %%
# 自动搜索
# 以32为倍数先搜一波
# @TODO: 探索更低的倍数，以降低padding的额外性能损耗
## 拆分为2个kenerl, 一个kernel用于计算, 一个kernel用于汇总结果. 两个kernel的工作组可以分别搜索提高搜索效率
## 计算kernel搜索
def auto_tune(record_file: str):
    from typing import Union
    # tz = rsplit_factor
    def search(vf: int, pr: int, bx: int, tx: int, ty: int, tz: int):
        """search by workgroup

        Args:
            blockIdxX (_type_): blockIdx.x
            threadIdxX (_type_): threadIdx.x
            vectorize_output (_type_): 输出的vectorize参数, 决定单线程输出多少个结果
            vectorize_input (list, optional): 输入X拷贝到shared_memory时的vectorize参数, 一般为4或8

        Returns:
            _type_: _description_
        """
        rsplit_factor = tz
        r_outter_loop = 344 // rsplit_factor
        assert 344 % rsplit_factor == 0, "344 is not divisible by rsplit_factor"

        @I.ir_module
        class ModuleToManual:


            @T.prim_func(private=False)
            #fused_decode2_fused_NT_matmul3_add_after
            def main(
                lv50: T.Buffer((T.int64(1376), T.int64(4096)), "uint32"),
                lv51: T.Buffer((T.int64(344), T.int64(4096)), "float16"),
                p_lv5: T.handle,
                p_lv3: T.handle,
                p_output0: T.handle,
            ):
                T.func_attr({"tir.noalias": T.bool(True), "tir.is_scheduled": 1})
                n = T.int64()
                lv5 = T.match_buffer(p_lv5, (T.int64(1), n, T.int64(11008)), "float16")
                lv3 = T.match_buffer(p_lv3, (T.int64(1), n, T.int64(4096)), "float16")
                p_output0_intermediate = T.match_buffer(
                    p_output0, (T.int64(1), n, T.int64(4096)), "float16"
                )
                # with T.block("root"):
                decode_local = T.alloc_buffer(
                    (T.int64(11008), T.int64(4096)), "float16", scope="local"
                )
                lv50_local = T.alloc_buffer((T.int64(1376), T.int64(4096)), "uint32", scope="local")
                lv51_local = T.alloc_buffer((T.int64(344), T.int64(4096)), "float16", scope="local")
                lv5_pad_local = T.alloc_buffer(
                    (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(11008)),
                    "float16",
                    scope="local",
                )
                var_NT_matmul_intermediate_pad_local = T.alloc_buffer(
                    (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(4096)),
                    "float16",
                    scope="local",
                )

                var_NT_matmul_intermediate_pad_rf = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16")
                var_NT_matmul_intermediate_pad_rf_local = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16", scope = "local")
        
                BlockIdx_x = bx#32
                # n = 32
                # BlockIdx_y = (n+31)//32 * 32 # 这里32是假设输入为32的倍数, //32的32 = thready * 
                ThreadIdx_x = tx#16 * 3
                ThreadIdx_y = ty#8
                vectorize_factor = vf#8
                # processed_columns_per_thread = vectorize_factor# w_y / (BlockIdx_x * ThreadIdx_x) == vectorize_factor
                processed_rows_per_thread = pr#4
                for i0_i1_fused_0_i0_i1_fused_1_0_fused in T.thread_binding(
                    (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
                ):
                    for i2_0 in T.thread_binding(T.int64(BlockIdx_x), thread="blockIdx.x"):
                        for i0_i1_fused_1_1 in T.thread_binding(T.int64(ThreadIdx_y), thread="threadIdx.y"):
                            for i2_1 in T.thread_binding(T.int64(ThreadIdx_x), thread="threadIdx.x"):
                                for k_outter in T.thread_binding(T.int64(rsplit_factor), thread="threadIdx.z"):
                                    for i0_i1_fused_1_2_init in range(T.int64(processed_rows_per_thread)):
                                        for i2_2_init in T.vectorized(T.int64(vectorize_factor)):
                                            with T.block("NT_matmul_init"):
                                                vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                                v_i1 = T.axis.spatial(
                                                    (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                                    i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                                    + i0_i1_fused_1_1 * processed_rows_per_thread
                                                    + i0_i1_fused_1_2_init,
                                                )
                                                v_i2 = T.axis.spatial(
                                                    T.int64(4096),
                                                    i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + i2_2_init,
                                                )
                                                T.reads()
                                                T.writes(
                                                    var_NT_matmul_intermediate_pad_rf_local[
                                                        T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                    ]
                                                )
                                                var_NT_matmul_intermediate_pad_rf_local[
                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                ] = T.float16(0)
                                    for k_0 in range(T.int64(r_outter_loop)):
                                        for ax0 in range(T.int64(1)):
                                            for ax1 in T.vectorized(T.int64(vectorize_factor)):
                                                with T.block("lv51_local"):
                                                    v0 = T.axis.spatial(T.int64(344), k_outter * r_outter_loop + k_0 + ax0)
                                                    v1 = T.axis.spatial(
                                                        T.int64(4096),
                                                        i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax1,
                                                    )
                                                    T.reads(lv51[v0, v1])
                                                    T.writes(lv51_local[v0, v1])
                                                    lv51_local[v0, v1] = lv51[v0, v1]
                                        for k_1 in range(T.int64(4)):
                                            for ax0 in range(T.int64(1)):
                                                for ax1 in T.vectorized(vectorize_factor):
                                                    with T.block("lv50_local"):
                                                        v0 = T.axis.spatial(
                                                            T.int64(1376), k_outter * r_outter_loop * T.int64(4) + k_0 * T.int64(4) + k_1 + ax0
                                                        )
                                                        v1 = T.axis.spatial(
                                                            T.int64(4096),
                                                            i2_0 * (ThreadIdx_x * vectorize_factor)
                                                            + i2_1 * vectorize_factor
                                                            + ax1,
                                                        )
                                                        T.reads(lv50[v0, v1])
                                                        T.writes(lv50_local[v0, v1])
                                                        lv50_local[v0, v1] = lv50[v0, v1]
                                            for k_2 in range(T.int64(8)):
                                                for ax0 in range(T.int64(1)):
                                                    for ax1 in T.vectorized(vectorize_factor):
                                                        with T.block("decode"):
                                                            v_i = T.axis.spatial(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2
                                                                + ax0,
                                                            )
                                                            v_j = T.axis.spatial(
                                                                T.int64(4096),
                                                                i2_0 * (ThreadIdx_x * vectorize_factor)
                                                                + i2_1 * vectorize_factor
                                                                + ax1,
                                                            )
                                                            T.reads(
                                                                lv50_local[v_i // T.int64(8), v_j],
                                                                lv51_local[v_i // T.int64(32), v_j],
                                                            )
                                                            T.writes(decode_local[v_i, v_j])
                                                            decode_local[v_i, v_j] = (
                                                                T.Cast(
                                                                    "float16",
                                                                    T.bitwise_and(
                                                                        T.shift_right(
                                                                            lv50_local[
                                                                                v_i // T.int64(8), v_j
                                                                            ],
                                                                            T.Cast(
                                                                                "uint32",
                                                                                v_i % T.int64(8),
                                                                            )
                                                                            * T.uint32(4),
                                                                        ),
                                                                        T.uint32(15),
                                                                    ),
                                                                )
                                                                - T.float16(7)
                                                            ) * lv51_local[v_i // T.int64(32), v_j]
                                                for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                                    for ax2 in T.vectorized(T.int64(1)):
                                                        with T.block("lv5_pad_local"):
                                                            v0 = T.axis.spatial(T.int64(1), ax0)
                                                            v1 = T.axis.spatial(
                                                                (n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                                * T.int64(32)
                                                                + i0_i1_fused_1_1 * processed_rows_per_thread
                                                                + ax1,
                                                            )
                                                            v2 = T.axis.spatial(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2
                                                                + ax2,
                                                            )
                                                            T.reads(lv5[v0, v1, v2])
                                                            T.writes(lv5_pad_local[v0, v1, v2])
                                                            lv5_pad_local[v0, v1, v2] = T.if_then_else(
                                                                v1 < n, lv5[v0, v1, v2], T.float16(0)
                                                            )
                                                for i0_i1_fused_1_2 in range(processed_rows_per_thread):
                                                    for i2_2 in T.vectorized(vectorize_factor):
                                                        with T.block("NT_matmul_update"):
                                                            vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                            v_i0 = T.axis.spatial(
                                                                T.int64(1), T.int64(0)
                                                            )
                                                            v_i1 = T.axis.spatial(
                                                                (n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                                * T.int64(32)
                                                                + i0_i1_fused_1_1 * processed_rows_per_thread
                                                                + i0_i1_fused_1_2,
                                                            )
                                                            v_i2 = T.axis.spatial(
                                                                T.int64(4096),
                                                                i2_0 * (ThreadIdx_x * vectorize_factor)
                                                                + i2_1 * vectorize_factor
                                                                + i2_2,
                                                            )
                                                            v_k = T.axis.reduce(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2,
                                                            )
                                                            T.reads(
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ],
                                                                lv5_pad_local[v_i0, v_i1, v_k],
                                                                decode_local[v_k, v_i2],
                                                            )
                                                            T.writes(
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ]
                                                            )
                                                            var_NT_matmul_intermediate_pad_rf_local[
                                                                T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                            ] = (
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ]
                                                                + lv5_pad_local[v_i0, v_i1, v_k]
                                                                * decode_local[v_k, v_i2]
                                                            )
                                    for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                        for ax2 in T.vectorized(vectorize_factor):
                                            with T.block("var_NT_matmul_intermediate_pad_local"):
                                                vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                v0 = T.axis.spatial(T.int64(1), ax0)
                                                v1 = T.axis.spatial(
                                                    (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                                    i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                                    + i0_i1_fused_1_1 * processed_rows_per_thread
                                                    + ax1,
                                                )
                                                v2 = T.axis.spatial(
                                                    T.int64(4096),
                                                    i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax2,
                                                )
                                                T.reads(
                                                    lv3[v0, v1, v2],
                                                    var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2],
                                                )
                                                T.writes(var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2])
                                                if v1 < n:
                                                    var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2] = (
                                                        var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2]
                                                        )
                ## sum(sub_reduce), sub_reduce shape: [rfactor, 1, n, 4096]
                ### reuduce axis: rfactor
                ### spatial axes: [1, n, 4096]
                #### threadIndex 划分:
                ## blockIdx.y: 处理by个32行数据
                ## blockIdx.x: 和tx及vfactor配合, 处理4096个columns数据, 也可能处理多行(rows_per_thread)
                ## threadIdx.x: ref to blockIdx.x
                ## threadIdx.y: 与rows_per_thread配合处理32行数据
                REDUCE_BX = 16
                REDUCE_TX = 32
                REDUCE_TY = 16
                REDUCE_VFACTOR = 8
                REDUCE_ROWS_PER_THREAD = 32 // REDUCE_TY
                for sp_row_by in T.thread_binding(
                    (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
                ):
                    for sp_col_bx in T.thread_binding(T.int64(REDUCE_BX), thread="blockIdx.x"):
                        for sp_col_tx in T.thread_binding(T.int64(REDUCE_TX), thread="threadIdx.x"):
                            for sp_row_ty in T.thread_binding(T.int64(REDUCE_TY), thread="threadIdx.y"):
                                for ax0, ax1 in T.grid(T.int64(1), REDUCE_ROWS_PER_THREAD):
                                    for sp_col_vfactor in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                        for k_0_0 in range(T.int64(rsplit_factor)):
                                            with T.block("matmul_update"):
                                                vk_0_0 = T.axis.reduce(T.int64(rsplit_factor), k_0_0)
                                                v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                                v_i1 = T.axis.spatial((n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                sp_row_by * T.int64(32)
                                                                + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                                + ax1)
                                                v_i2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + sp_col_vfactor)
                                                T.reads(var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2])
                                                T.writes(var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2])
                                                with T.init():
                                                    var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = T.float16(0)
                                                var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] + var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2]
                                for ax0, ax1 in T.grid(T.int64(1), T.int64(REDUCE_ROWS_PER_THREAD)):
                                    for ax2 in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                        with T.block("output"):
                                            v0 = T.axis.spatial(T.int64(1), T.int64(0))
                                            v1 = T.axis.spatial((n + T.int64(31))
                                                            // T.int64(32)
                                                            * T.int64(32),
                                                            sp_row_by * T.int64(32)
                                                            + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                            + ax1)
                                            v2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + ax2)
                                            T.reads(lv3[v0, v1, v2], p_output0_intermediate[v0, v1, v2])
                                            T.writes(p_output0_intermediate[v0, v1, v2])
                                            if v1 < n:
                                                p_output0_intermediate[v0, v1, v2] = (lv3[v0, v1, v2]
                                                                    + var_NT_matmul_intermediate_pad_local[v0, v1, v2])
        return tvm.tir.Schedule(ModuleToManual).mod

    BlockIdx_x = [None] # 32
    # n = 32
    # BlockIdx_y = (n+31)//32 * 32 # 这里32是假设输入为32的倍数, //32的32 = thready * 
    ThreadIdx_x = [16, 32, 48, 64, 96, 128, 192, 256, 384, 512]#16 * 3
    ThreadIdx_z = [2, 4, 8]
    # ThreadIdx_y = 8 # = 32 / processed_rows_per_thread
    vectorize_factor = [2, 4, 8]# 8
    # processed_columns_per_thread = vectorize_factor# w_y / (BlockIdx_x * ThreadIdx_x) == vectorize_factor
    processed_rows_per_thread = [1, 2, 4, 8, 16]#4
    task_index = 0
    total_task_num = len(vectorize_factor)*len(BlockIdx_x)*len(ThreadIdx_x)*len(processed_rows_per_thread)*len(ThreadIdx_z)
    records = {}
    print(f"Total tasks: {total_task_num}")
    # try:
    vectorize_factor_r = vectorize_factor[::-1]
    processed_rows_per_thread_r = processed_rows_per_thread[::-1]
    ThreadIdx_x_r = ThreadIdx_x[::-1]
    ThreadIdx_z_r = ThreadIdx_z[::-1]
    # table
    write_interval = 5
    from prettytable import PrettyTable
    table = PrettyTable()
    table.field_names = ["vectorize_factor", "processed_rows_per_thread", "blockIdx.x", "threadIdx.x", "threadIdx.y", "threadIdx.z", "cost(ms)"]
    for vf in vectorize_factor_r:
        for pr in processed_rows_per_thread_r:
            for tx in ThreadIdx_x_r:
                for tz in ThreadIdx_z_r:
                    task_index = task_index + 1
                    import math
                    bx = math.ceil(w_y /(vf * tx))
                    ty = math.ceil(32//pr)
                    if bx * tx * vf > w_y or tx*ty*tz > 1024 or 32 % pr != 0 or 344 % tz != 0: # w_y为输出列数, 工作组和vectorize相乘不能大于该数字
                        print(f"search record [{task_index}/{total_task_num}]: skip {vf} {pr} {bx} {tx} {ty}")
                        continue
                    if w_y % (vf * tx) != 0:
                        print(f"search record [{task_index}/{total_task_num}]: skip because bx isn't divisible {vf} {pr} {bx} {tx} {ty}")
                        continue
                    print(f"search record [{task_index}/{total_task_num}]: start run {vf} {pr} {bx} {tx} {ty}")
                    # vf: int, pr: int, bx: int, tx: int, ty: int):
                    mod_deploy = search(vf, pr, bx, tx, ty, tz)
                    cost = test_opencl(mod_deploy, "search")
                    print("=====")
                    records[(vf, pr, bx, tx, ty, tz)] = cost
                    table.add_row([vf, pr, bx, tx, ty, tz, cost])
                    if task_index % write_interval == 0:
                        with open(record_file, 'wt') as f:
                            f.write(table.get_csv_string())
    print("================================")
    print(table)
    with open(record_file, 'wt') as f:
        f.write(table.get_csv_string())
    
    # record_sorted = sorted(record.items(), key=lambda x: x[1][0], reverse=True)
auto_tune("./manual_tune/down_n_split_reduce_tune_record_caclulate_2.csv")
# Out:
# Total tasks: 450
# search record [1/450]: skip 8 16 1 512 2
# search record [2/450]: skip 8 16 1 512 2
# search record [3/450]: skip 8 16 1 512 2
# search record [4/450]: skip 8 16 2 384 2
# search record [5/450]: skip 8 16 2 384 2
# search record [6/450]: skip 8 16 2 384 2
# search record [7/450]: skip 8 16 2 256 2
# search record [8/450]: skip 8 16 2 256 2
# search record [9/450]: start run 8 16 2 256 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# /data/workspace/llm/github/new_wksp/tvm-unity/python/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# Connect to device done.
# evaluator[search] GEMV-Blocking: 159.669576ms with loop 32
# evaluator[search] GEMV-Blocking: 7.693430GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [10/450]: skip 8 16 3 192 2
# search record [11/450]: skip 8 16 3 192 2
# search record [12/450]: skip 8 16 3 192 2
# search record [13/450]: skip 8 16 4 128 2
# search record [14/450]: start run 8 16 4 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 79.563712ms with loop 32
# evaluator[search] GEMV-Blocking: 15.439284GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [15/450]: start run 8 16 4 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 91.599096ms with loop 32
# evaluator[search] GEMV-Blocking: 13.410687GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [16/450]: skip 8 16 6 96 2
# search record [17/450]: skip 8 16 6 96 2
# search record [18/450]: skip 8 16 6 96 2
# search record [19/450]: start run 8 16 8 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 39.734280ms with loop 32
# evaluator[search] GEMV-Blocking: 30.915542GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [20/450]: start run 8 16 8 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 46.298848ms with loop 32
# evaluator[search] GEMV-Blocking: 26.532124GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [21/450]: start run 8 16 8 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 46.258960ms with loop 32
# evaluator[search] GEMV-Blocking: 26.555002GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [22/450]: skip 8 16 11 48 2
# search record [23/450]: skip 8 16 11 48 2
# search record [24/450]: skip 8 16 11 48 2
# search record [25/450]: start run 8 16 16 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 47.894832ms with loop 32
# evaluator[search] GEMV-Blocking: 25.648003GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [26/450]: start run 8 16 16 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 47.571312ms with loop 32
# evaluator[search] GEMV-Blocking: 25.822428GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [27/450]: start run 8 16 16 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 84.232504ms with loop 32
# evaluator[search] GEMV-Blocking: 14.583524GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [28/450]: start run 8 16 32 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 35.697376ms with loop 32
# evaluator[search] GEMV-Blocking: 34.411683GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [29/450]: start run 8 16 32 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 63.729552ms with loop 32
# evaluator[search] GEMV-Blocking: 19.275309GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [30/450]: start run 8 16 32 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 126.357728ms with loop 32
# evaluator[search] GEMV-Blocking: 9.721659GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [31/450]: skip 8 8 1 512 4
# search record [32/450]: skip 8 8 1 512 4
# search record [33/450]: skip 8 8 1 512 4
# search record [34/450]: skip 8 8 2 384 4
# search record [35/450]: skip 8 8 2 384 4
# search record [36/450]: skip 8 8 2 384 4
# search record [37/450]: skip 8 8 2 256 4
# search record [38/450]: skip 8 8 2 256 4
# search record [39/450]: skip 8 8 2 256 4
# search record [40/450]: skip 8 8 3 192 4
# search record [41/450]: skip 8 8 3 192 4
# search record [42/450]: skip 8 8 3 192 4
# search record [43/450]: skip 8 8 4 128 4
# search record [44/450]: skip 8 8 4 128 4
# search record [45/450]: start run 8 8 4 128 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 78.123728ms with loop 32
# evaluator[search] GEMV-Blocking: 15.723863GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [46/450]: skip 8 8 6 96 4
# search record [47/450]: skip 8 8 6 96 4
# search record [48/450]: skip 8 8 6 96 4
# search record [49/450]: skip 8 8 8 64 4
# search record [50/450]: start run 8 8 8 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 39.614512ms with loop 32
# evaluator[search] GEMV-Blocking: 31.009010GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [51/450]: start run 8 8 8 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 47.352088ms with loop 32
# evaluator[search] GEMV-Blocking: 25.941977GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [52/450]: skip 8 8 11 48 4
# search record [53/450]: skip 8 8 11 48 4
# search record [54/450]: skip 8 8 11 48 4
# search record [55/450]: start run 8 8 16 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 39.755744ms with loop 32
# evaluator[search] GEMV-Blocking: 30.898850GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [56/450]: start run 8 8 16 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 40.748200ms with loop 32
# evaluator[search] GEMV-Blocking: 30.146283GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [57/450]: start run 8 8 16 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 49.467784ms with loop 32
# evaluator[search] GEMV-Blocking: 24.832460GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [58/450]: start run 8 8 32 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 29.645000ms with loop 32
# evaluator[search] GEMV-Blocking: 41.437233GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [59/450]: start run 8 8 32 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 29.941680ms with loop 32
# evaluator[search] GEMV-Blocking: 41.026649GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [60/450]: start run 8 8 32 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 48.142120ms with loop 32
# evaluator[search] GEMV-Blocking: 25.516259GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [61/450]: skip 8 4 1 512 8
# search record [62/450]: skip 8 4 1 512 8
# search record [63/450]: skip 8 4 1 512 8
# search record [64/450]: skip 8 4 2 384 8
# search record [65/450]: skip 8 4 2 384 8
# search record [66/450]: skip 8 4 2 384 8
# search record [67/450]: skip 8 4 2 256 8
# search record [68/450]: skip 8 4 2 256 8
# search record [69/450]: skip 8 4 2 256 8
# search record [70/450]: skip 8 4 3 192 8
# search record [71/450]: skip 8 4 3 192 8
# search record [72/450]: skip 8 4 3 192 8
# search record [73/450]: skip 8 4 4 128 8
# search record [74/450]: skip 8 4 4 128 8
# search record [75/450]: skip 8 4 4 128 8
# search record [76/450]: skip 8 4 6 96 8
# search record [77/450]: skip 8 4 6 96 8
# search record [78/450]: skip 8 4 6 96 8
# search record [79/450]: skip 8 4 8 64 8
# search record [80/450]: skip 8 4 8 64 8
# search record [81/450]: start run 8 4 8 64 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 9.194560ms with loop 32
# evaluator[search] GEMV-Blocking: 133.601476GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [82/450]: skip 8 4 11 48 8
# search record [83/450]: skip 8 4 11 48 8
# search record [84/450]: skip 8 4 11 48 8
# search record [85/450]: skip 8 4 16 32 8
# search record [86/450]: start run 8 4 16 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.800232ms with loop 32
# evaluator[search] GEMV-Blocking: 139.588000GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [87/450]: start run 8 4 16 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 9.293224ms with loop 32
# evaluator[search] GEMV-Blocking: 132.183060GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [88/450]: start run 8 4 32 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.549976ms with loop 32
# evaluator[search] GEMV-Blocking: 187.543708GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [89/450]: start run 8 4 32 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.839680ms with loop 32
# evaluator[search] GEMV-Blocking: 179.600037GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [90/450]: start run 8 4 32 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.083848ms with loop 32
# evaluator[search] GEMV-Blocking: 151.958174GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [91/450]: skip 8 2 1 512 16
# search record [92/450]: skip 8 2 1 512 16
# search record [93/450]: skip 8 2 1 512 16
# search record [94/450]: skip 8 2 2 384 16
# search record [95/450]: skip 8 2 2 384 16
# search record [96/450]: skip 8 2 2 384 16
# search record [97/450]: skip 8 2 2 256 16
# search record [98/450]: skip 8 2 2 256 16
# search record [99/450]: skip 8 2 2 256 16
# search record [100/450]: skip 8 2 3 192 16
# search record [101/450]: skip 8 2 3 192 16
# search record [102/450]: skip 8 2 3 192 16
# search record [103/450]: skip 8 2 4 128 16
# search record [104/450]: skip 8 2 4 128 16
# search record [105/450]: skip 8 2 4 128 16
# search record [106/450]: skip 8 2 6 96 16
# search record [107/450]: skip 8 2 6 96 16
# search record [108/450]: skip 8 2 6 96 16
# search record [109/450]: skip 8 2 8 64 16
# search record [110/450]: skip 8 2 8 64 16
# search record [111/450]: skip 8 2 8 64 16
# search record [112/450]: skip 8 2 11 48 16
# search record [113/450]: skip 8 2 11 48 16
# search record [114/450]: skip 8 2 11 48 16
# search record [115/450]: skip 8 2 16 32 16
# search record [116/450]: skip 8 2 16 32 16
# search record [117/450]: start run 8 2 16 32 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 12.051480ms with loop 32
# evaluator[search] GEMV-Blocking: 101.929953GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [118/450]: skip 8 2 32 16 16
# search record [119/450]: start run 8 2 32 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 9.073264ms with loop 32
# evaluator[search] GEMV-Blocking: 135.387528GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [120/450]: start run 8 2 32 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 9.409544ms with loop 32
# evaluator[search] GEMV-Blocking: 130.549024GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [121/450]: skip 8 1 1 512 32
# search record [122/450]: skip 8 1 1 512 32
# search record [123/450]: skip 8 1 1 512 32
# search record [124/450]: skip 8 1 2 384 32
# search record [125/450]: skip 8 1 2 384 32
# search record [126/450]: skip 8 1 2 384 32
# search record [127/450]: skip 8 1 2 256 32
# search record [128/450]: skip 8 1 2 256 32
# search record [129/450]: skip 8 1 2 256 32
# search record [130/450]: skip 8 1 3 192 32
# search record [131/450]: skip 8 1 3 192 32
# search record [132/450]: skip 8 1 3 192 32
# search record [133/450]: skip 8 1 4 128 32
# search record [134/450]: skip 8 1 4 128 32
# search record [135/450]: skip 8 1 4 128 32
# search record [136/450]: skip 8 1 6 96 32
# search record [137/450]: skip 8 1 6 96 32
# search record [138/450]: skip 8 1 6 96 32
# search record [139/450]: skip 8 1 8 64 32
# search record [140/450]: skip 8 1 8 64 32
# search record [141/450]: skip 8 1 8 64 32
# search record [142/450]: skip 8 1 11 48 32
# search record [143/450]: skip 8 1 11 48 32
# search record [144/450]: skip 8 1 11 48 32
# search record [145/450]: skip 8 1 16 32 32
# search record [146/450]: skip 8 1 16 32 32
# search record [147/450]: skip 8 1 16 32 32
# search record [148/450]: skip 8 1 32 16 32
# search record [149/450]: skip 8 1 32 16 32
# search record [150/450]: start run 8 1 32 16 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 14.583416ms with loop 32
# evaluator[search] GEMV-Blocking: 84.233131GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [151/450]: skip 4 16 2 512 2
# search record [152/450]: skip 4 16 2 512 2
# search record [153/450]: skip 4 16 2 512 2
# search record [154/450]: skip 4 16 3 384 2
# search record [155/450]: skip 4 16 3 384 2
# search record [156/450]: skip 4 16 3 384 2
# search record [157/450]: skip 4 16 4 256 2
# search record [158/450]: skip 4 16 4 256 2
# search record [159/450]: start run 4 16 4 256 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 285.324400ms with loop 32
# evaluator[search] GEMV-Blocking: 4.305299GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [160/450]: skip 4 16 6 192 2
# search record [161/450]: skip 4 16 6 192 2
# search record [162/450]: skip 4 16 6 192 2
# search record [163/450]: skip 4 16 8 128 2
# search record [164/450]: start run 4 16 8 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 142.226824ms with loop 32
# evaluator[search] GEMV-Blocking: 8.636956GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [165/450]: start run 4 16 8 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 153.955224ms with loop 32
# evaluator[search] GEMV-Blocking: 7.978987GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [166/450]: skip 4 16 11 96 2
# search record [167/450]: skip 4 16 11 96 2
# search record [168/450]: skip 4 16 11 96 2
# search record [169/450]: start run 4 16 16 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 146.536864ms with loop 32
# evaluator[search] GEMV-Blocking: 8.382920GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [170/450]: start run 4 16 16 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 156.273688ms with loop 32
# evaluator[search] GEMV-Blocking: 7.860612GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [171/450]: start run 4 16 16 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 173.308456ms with loop 32
# evaluator[search] GEMV-Blocking: 7.087980GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [172/450]: skip 4 16 22 48 2
# search record [173/450]: skip 4 16 22 48 2
# search record [174/450]: skip 4 16 22 48 2
# search record [175/450]: start run 4 16 32 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 118.518672ms with loop 32
# evaluator[search] GEMV-Blocking: 10.364669GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [176/450]: start run 4 16 32 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 131.817984ms with loop 32
# evaluator[search] GEMV-Blocking: 9.318962GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [177/450]: start run 4 16 32 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 194.252040ms with loop 32
# evaluator[search] GEMV-Blocking: 6.323778GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [178/450]: start run 4 16 64 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 132.443752ms with loop 32
# evaluator[search] GEMV-Blocking: 9.274932GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [179/450]: start run 4 16 64 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 193.472416ms with loop 32
# evaluator[search] GEMV-Blocking: 6.349261GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [180/450]: start run 4 16 64 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 388.385496ms with loop 32
# evaluator[search] GEMV-Blocking: 3.162854GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [181/450]: skip 4 8 2 512 4
# search record [182/450]: skip 4 8 2 512 4
# search record [183/450]: skip 4 8 2 512 4
# search record [184/450]: skip 4 8 3 384 4
# search record [185/450]: skip 4 8 3 384 4
# search record [186/450]: skip 4 8 3 384 4
# search record [187/450]: skip 4 8 4 256 4
# search record [188/450]: skip 4 8 4 256 4
# search record [189/450]: skip 4 8 4 256 4
# search record [190/450]: skip 4 8 6 192 4
# search record [191/450]: skip 4 8 6 192 4
# search record [192/450]: skip 4 8 6 192 4
# search record [193/450]: skip 4 8 8 128 4
# search record [194/450]: skip 4 8 8 128 4
# search record [195/450]: start run 4 8 8 128 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 11.829184ms with loop 32
# evaluator[search] GEMV-Blocking: 103.845437GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [196/450]: skip 4 8 11 96 4
# search record [197/450]: skip 4 8 11 96 4
# search record [198/450]: skip 4 8 11 96 4
# search record [199/450]: skip 4 8 16 64 4
# search record [200/450]: start run 4 8 16 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 11.582032ms with loop 32
# evaluator[search] GEMV-Blocking: 106.061422GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [201/450]: start run 4 8 16 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 11.711744ms with loop 32
# evaluator[search] GEMV-Blocking: 104.886752GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [202/450]: skip 4 8 22 48 4
# search record [203/450]: skip 4 8 22 48 4
# search record [204/450]: skip 4 8 22 48 4
# search record [205/450]: start run 4 8 32 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.298544ms with loop 32
# evaluator[search] GEMV-Blocking: 148.026784GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [206/450]: start run 4 8 32 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.815488ms with loop 32
# evaluator[search] GEMV-Blocking: 139.346430GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [207/450]: start run 4 8 32 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 10.680776ms with loop 32
# evaluator[search] GEMV-Blocking: 115.011005GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [208/450]: start run 4 8 64 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.322480ms with loop 32
# evaluator[search] GEMV-Blocking: 147.601050GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [209/450]: start run 4 8 64 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.885656ms with loop 32
# evaluator[search] GEMV-Blocking: 138.246043GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [210/450]: start run 4 8 64 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 10.782000ms with loop 32
# evaluator[search] GEMV-Blocking: 113.931254GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [211/450]: skip 4 4 2 512 8
# search record [212/450]: skip 4 4 2 512 8
# search record [213/450]: skip 4 4 2 512 8
# search record [214/450]: skip 4 4 3 384 8
# search record [215/450]: skip 4 4 3 384 8
# search record [216/450]: skip 4 4 3 384 8
# search record [217/450]: skip 4 4 4 256 8
# search record [218/450]: skip 4 4 4 256 8
# search record [219/450]: skip 4 4 4 256 8
# search record [220/450]: skip 4 4 6 192 8
# search record [221/450]: skip 4 4 6 192 8
# search record [222/450]: skip 4 4 6 192 8
# search record [223/450]: skip 4 4 8 128 8
# search record [224/450]: skip 4 4 8 128 8
# search record [225/450]: skip 4 4 8 128 8
# search record [226/450]: skip 4 4 11 96 8
# search record [227/450]: skip 4 4 11 96 8
# search record [228/450]: skip 4 4 11 96 8
# search record [229/450]: skip 4 4 16 64 8
# search record [230/450]: skip 4 4 16 64 8
# search record [231/450]: start run 4 4 16 64 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 10.198832ms with loop 32
# evaluator[search] GEMV-Blocking: 120.445830GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [232/450]: skip 4 4 22 48 8
# search record [233/450]: skip 4 4 22 48 8
# search record [234/450]: skip 4 4 22 48 8
# search record [235/450]: skip 4 4 32 32 8
# search record [236/450]: start run 4 4 32 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 7.791640ms with loop 32
# evaluator[search] GEMV-Blocking: 157.657025GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [237/450]: start run 4 4 32 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 8.217432ms with loop 32
# evaluator[search] GEMV-Blocking: 149.487916GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
# ...
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [418/450]: skip 2 2 128 16 16
# search record [419/450]: start run 2 2 128 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 14.961976ms with loop 32
# evaluator[search] GEMV-Blocking: 82.101908GFLOPS
# [[[-17920. -19680. -18400. ... -17616. -17920. -17728.]
#   [-17984. -19744. -18560. ... -17760. -18016. -17824.]
#   [-18144. -19904. -18528. ... -17952. -17984. -17760.]
#   ...
#   [-18272. -19904. -18528. ... -17888. -18144. -17856.]
#   [-17968. -19696. -18464. ... -17568. -17872. -17584.]
#   [-18208. -20064. -18672. ... -17760. -18176. -17664.]]]
# [-17920. -19680. -18400. -18080. -18336. -19168. -18144. -18240. -17168.
#  -17824. -18336. -17968. -18944. -19328. -19264. -18592. -18928. -17648.
#  -18496. -18176.]
# =====
# search record [420/450]: start run 2 2 128 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 15.586992ms with loop 32
# evaluator[search] GEMV-Blocking: 78.809740GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# search record [421/450]: skip 2 1 4 512 32
# search record [422/450]: skip 2 1 4 512 32
# search record [423/450]: skip 2 1 4 512 32
# search record [424/450]: skip 2 1 6 384 32
# search record [425/450]: skip 2 1 6 384 32
# search record [426/450]: skip 2 1 6 384 32
# search record [427/450]: skip 2 1 8 256 32
# search record [428/450]: skip 2 1 8 256 32
# search record [429/450]: skip 2 1 8 256 32
# search record [430/450]: skip 2 1 11 192 32
# search record [431/450]: skip 2 1 11 192 32
# search record [432/450]: skip 2 1 11 192 32
# search record [433/450]: skip 2 1 16 128 32
# search record [434/450]: skip 2 1 16 128 32
# search record [435/450]: skip 2 1 16 128 32
# search record [436/450]: skip 2 1 22 96 32
# search record [437/450]: skip 2 1 22 96 32
# search record [438/450]: skip 2 1 22 96 32
# search record [439/450]: skip 2 1 32 64 32
# search record [440/450]: skip 2 1 32 64 32
# search record [441/450]: skip 2 1 32 64 32
# search record [442/450]: skip 2 1 43 48 32
# search record [443/450]: skip 2 1 43 48 32
# search record [444/450]: skip 2 1 43 48 32
# search record [445/450]: skip 2 1 64 32 32
# search record [446/450]: skip 2 1 64 32 32
# search record [447/450]: skip 2 1 64 32 32
# search record [448/450]: skip 2 1 128 16 32
# search record [449/450]: skip 2 1 128 16 32
# search record [450/450]: start run 2 1 128 16 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 16.004440ms with loop 32
# evaluator[search] GEMV-Blocking: 76.754125GFLOPS
# [[[-16496. -17728. -16768. ... -16192. -16576. -16256.]
#   [-16448. -17792. -16768. ... -16288. -16560. -16448.]
#   [-16512. -17792. -16704. ... -16464. -16368. -16416.]
#   ...
#   [-16640. -17872. -16704. ... -16480. -16688. -16432.]
#   [-16544. -17616. -16768. ... -16240. -16352. -16224.]
#   [-16576. -17920. -16768. ... -16384. -16592. -16416.]]]
# [-16496. -17728. -16768. -16640. -16800. -17440. -16736. -16736. -16088.
#  -16448. -16816. -16384. -17584. -17376. -17760. -17056. -17184. -16336.
#  -16800. -16832.]
# =====
# ================================
# +------------------+---------------------------+------------+-------------+-------------+-------------+--------------------+
# | vectorize_factor | processed_rows_per_thread | blockIdx.x | threadIdx.x | threadIdx.y | threadIdx.z |      cost(ms)      |
# +------------------+---------------------------+------------+-------------+-------------+-------------+--------------------+
# |        8         |             16            |     2      |     256     |      2      |      2      |     159.669576     |
# |        8         |             16            |     4      |     128     |      2      |      4      |     79.563712      |
# |        8         |             16            |     4      |     128     |      2      |      2      |     91.599096      |
# |        8         |             16            |     8      |      64     |      2      |      8      |      39.73428      |
# |        8         |             16            |     8      |      64     |      2      |      4      |     46.298848      |
# |        8         |             16            |     8      |      64     |      2      |      2      |      46.25896      |
# |        8         |             16            |     16     |      32     |      2      |      8      |     47.894832      |
# |        8         |             16            |     16     |      32     |      2      |      4      |     47.571312      |
# |        8         |             16            |     16     |      32     |      2      |      2      |     84.232504      |
# |        8         |             16            |     32     |      16     |      2      |      8      |     35.697376      |
# |        8         |             16            |     32     |      16     |      2      |      4      |     63.729552      |
# |        8         |             16            |     32     |      16     |      2      |      2      | 126.35772800000001 |
# |        8         |             8             |     4      |     128     |      4      |      2      |     78.123728      |
# |        8         |             8             |     8      |      64     |      4      |      4      |     39.614512      |
# |        8         |             8             |     8      |      64     |      4      |      2      |     47.352088      |
# |        8         |             8             |     16     |      32     |      4      |      8      |     39.755744      |
# |        8         |             8             |     16     |      32     |      4      |      4      |      40.7482       |
# |        8         |             8             |     16     |      32     |      4      |      2      |     49.467784      |
# |        8         |             8             |     32     |      16     |      4      |      8      |       29.645       |
# |        8         |             8             |     32     |      16     |      4      |      4      |      29.94168      |
# |        8         |             8             |     32     |      16     |      4      |      2      |      48.14212      |
# |        8         |             4             |     8      |      64     |      8      |      2      |      9.19456       |
# |        8         |             4             |     16     |      32     |      8      |      4      |      8.800232      |
# |        8         |             4             |     16     |      32     |      8      |      2      |      9.293224      |
# |        8         |             4             |     32     |      16     |      8      |      8      |      6.549976      |
# |        8         |             4             |     32     |      16     |      8      |      4      |      6.83968       |
# |        8         |             4             |     32     |      16     |      8      |      2      |      8.083848      |
# |        8         |             2             |     16     |      32     |      16     |      2      |      12.05148      |
# |        8         |             2             |     32     |      16     |      16     |      4      |      9.073264      |
# |        8         |             2             |     32     |      16     |      16     |      2      |      9.409544      |
# |        8         |             1             |     32     |      16     |      32     |      2      |     14.583416      |
# |        4         |             16            |     4      |     256     |      2      |      2      |      285.3244      |
# |        4         |             16            |     8      |     128     |      2      |      4      |     142.226824     |
# |        4         |             16            |     8      |     128     |      2      |      2      |     153.955224     |
# |        4         |             16            |     16     |      64     |      2      |      8      |     146.536864     |
# |        4         |             16            |     16     |      64     |      2      |      4      |     156.273688     |
# |        4         |             16            |     16     |      64     |      2      |      2      |     173.308456     |
# |        4         |             16            |     32     |      32     |      2      |      8      |     118.518672     |
# |        4         |             16            |     32     |      32     |      2      |      4      |     131.817984     |
# |        4         |             16            |     32     |      32     |      2      |      2      |     194.25204      |
# |        4         |             16            |     64     |      16     |      2      |      8      |     132.443752     |
# |        4         |             16            |     64     |      16     |      2      |      4      |     193.472416     |
# |        4         |             16            |     64     |      16     |      2      |      2      |     388.385496     |
# |        4         |             8             |     8      |     128     |      4      |      2      |     11.829184      |
# |        4         |             8             |     16     |      64     |      4      |      4      |     11.582032      |
# |        4         |             8             |     16     |      64     |      4      |      2      |     11.711744      |
# |        4         |             8             |     32     |      32     |      4      |      8      |      8.298544      |
# |        4         |             8             |     32     |      32     |      4      |      4      |      8.815488      |
# |        4         |             8             |     32     |      32     |      4      |      2      |     10.680776      |
# |        4         |             8             |     64     |      16     |      4      |      8      |      8.32248       |
# |        4         |             8             |     64     |      16     |      4      |      4      |      8.885656      |
# |        4         |             8             |     64     |      16     |      4      |      2      |       10.782       |
# |        4         |             4             |     16     |      64     |      8      |      2      |     10.198832      |
# |        4         |             4             |     32     |      32     |      8      |      4      |      7.79164       |
# |        4         |             4             |     32     |      32     |      8      |      2      |      8.217432      |
# |        4         |             4             |     64     |      16     |      8      |      8      |      7.743832      |
# |        4         |             4             |     64     |      16     |      8      |      4      | 7.9060880000000004 |
# |        4         |             4             |     64     |      16     |      8      |      2      |      8.31656       |
# |        4         |             2             |     32     |      32     |      16     |      2      |     10.354888      |
# |        4         |             2             |     64     |      16     |      16     |      4      |      10.07188      |
# |        4         |             2             |     64     |      16     |      16     |      2      |     10.649536      |
# |        4         |             1             |     64     |      16     |      32     |      2      |     11.464904      |
# |        2         |             16            |     8      |     256     |      2      |      2      |     144.832408     |
# |        2         |             16            |     16     |     128     |      2      |      4      |     143.560368     |
# |        2         |             16            |     16     |     128     |      2      |      2      |     159.328552     |
# |        2         |             16            |     32     |      64     |      2      |      8      |     107.539488     |
# |        2         |             16            |     32     |      64     |      2      |      4      |     118.170424     |
# |        2         |             16            |     32     |      64     |      2      |      2      | 126.70580000000001 |
# |        2         |             16            |     64     |      32     |      2      |      8      |     121.210648     |
# |        2         |             16            |     64     |      32     |      2      |      4      |     129.267576     |
# |        2         |             16            |     64     |      32     |      2      |      2      |     238.160248     |
# |        2         |             16            |    128     |      16     |      2      |      8      |     118.437904     |
# |        2         |             16            |    128     |      16     |      2      |      4      |     217.51232      |
# |        2         |             16            |    128     |      16     |      2      |      2      |     421.659928     |
# |        2         |             8             |     16     |     128     |      4      |      2      |     19.295472      |
# |        2         |             8             |     32     |      64     |      4      |      4      |     14.495208      |
# |        2         |             8             |     32     |      64     |      4      |      2      |     14.906736      |
# |        2         |             8             |     64     |      32     |      4      |      8      |      14.20964      |
# |        2         |             8             |     64     |      32     |      4      |      4      |     14.481984      |
# |        2         |             8             |     64     |      32     |      4      |      2      |     15.050176      |
# |        2         |             8             |    128     |      16     |      4      |      8      |     13.129272      |
# |        2         |             8             |    128     |      16     |      4      |      4      |      13.33852      |
# |        2         |             8             |    128     |      16     |      4      |      2      |      13.6036       |
# |        2         |             4             |     32     |      64     |      8      |      2      |      13.96396      |
# |        2         |             4             |     64     |      32     |      8      |      4      |     13.619304      |
# |        2         |             4             |     64     |      32     |      8      |      2      |     14.048528      |
# |        2         |             4             |    128     |      16     |      8      |      8      |     12.425424      |
# |        2         |             4             |    128     |      16     |      8      |      4      |     12.646064      |
# |        2         |             4             |    128     |      16     |      8      |      2      |     13.048824      |
# |        2         |             2             |     64     |      32     |      16     |      2      |     16.592896      |
# |        2         |             2             |    128     |      16     |      16     |      4      |     14.961976      |
# |        2         |             2             |    128     |      16     |      16     |      2      |     15.586992      |
# |        2         |             1             |    128     |      16     |      32     |      2      |      16.00444      |
# +------------------+---------------------------+------------+-------------+-------------+-------------+--------------------+

# %%
# 自动搜索
## 结果汇集kernel搜索
def auto_tune_allreduce(record_file: str):
    from typing import Union
    # tz = rsplit_factor
    def search(vf: int, pr: int, bx: int, tx: int, ty: int):
        """search by workgroup

        Args:
            blockIdxX (_type_): blockIdx.x
            threadIdxX (_type_): threadIdx.x
            vectorize_output (_type_): 输出的vectorize参数, 决定单线程输出多少个结果
            vectorize_input (list, optional): 输入X拷贝到shared_memory时的vectorize参数, 一般为4或8

        Returns:
            _type_: _description_
        """
        rsplit_factor = 8
        r_outter_loop = 344 // rsplit_factor
        assert 344 % rsplit_factor == 0, "344 is not divisible by rsplit_factor"

        @I.ir_module
        class ModuleToManual:


            @T.prim_func(private=False)
            #fused_decode2_fused_NT_matmul3_add_after
            def main(
                lv50: T.Buffer((T.int64(1376), T.int64(4096)), "uint32"),
                lv51: T.Buffer((T.int64(344), T.int64(4096)), "float16"),
                p_lv5: T.handle,
                p_lv3: T.handle,
                p_output0: T.handle,
            ):
                T.func_attr({"tir.noalias": T.bool(True), "tir.is_scheduled": 1})
                n = T.int64()
                lv5 = T.match_buffer(p_lv5, (T.int64(1), n, T.int64(11008)), "float16")
                lv3 = T.match_buffer(p_lv3, (T.int64(1), n, T.int64(4096)), "float16")
                p_output0_intermediate = T.match_buffer(
                    p_output0, (T.int64(1), n, T.int64(4096)), "float16"
                )
                # with T.block("root"):
                decode_local = T.alloc_buffer(
                    (T.int64(11008), T.int64(4096)), "float16", scope="local"
                )
                lv50_local = T.alloc_buffer((T.int64(1376), T.int64(4096)), "uint32", scope="local")
                lv51_local = T.alloc_buffer((T.int64(344), T.int64(4096)), "float16", scope="local")
                lv5_pad_local = T.alloc_buffer(
                    (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(11008)),
                    "float16",
                    scope="local",
                )
                var_NT_matmul_intermediate_pad_local = T.alloc_buffer(
                    (T.int64(1), (n + T.int64(31)) // T.int64(32) * T.int64(32), T.int64(4096)),
                    "float16",
                    scope="local",
                )

                var_NT_matmul_intermediate_pad_rf = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16")
                var_NT_matmul_intermediate_pad_rf_local = T.alloc_buffer((rsplit_factor, 1, (n+31) // 32 * 32, 4096), "float16", scope = "local")
        
                BlockIdx_x = 32#32
                # n = 32
                # BlockIdx_y = (n+31)//32 * 32 # 这里32是假设输入为32的倍数, //32的32 = thready * 
                ThreadIdx_x = 16#16
                ThreadIdx_y = 8#8
                vectorize_factor = 8#8
                # processed_columns_per_thread = vectorize_factor# w_y / (BlockIdx_x * ThreadIdx_x) == vectorize_factor
                processed_rows_per_thread = 4#4
                for i0_i1_fused_0_i0_i1_fused_1_0_fused in T.thread_binding(
                    (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
                ):
                    for i2_0 in T.thread_binding(T.int64(BlockIdx_x), thread="blockIdx.x"):
                        for i0_i1_fused_1_1 in T.thread_binding(T.int64(ThreadIdx_y), thread="threadIdx.y"):
                            for i2_1 in T.thread_binding(T.int64(ThreadIdx_x), thread="threadIdx.x"):
                                for k_outter in T.thread_binding(T.int64(rsplit_factor), thread="threadIdx.z"):
                                    for i0_i1_fused_1_2_init in range(T.int64(processed_rows_per_thread)):
                                        for i2_2_init in T.vectorized(T.int64(vectorize_factor)):
                                            with T.block("NT_matmul_init"):
                                                vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                                v_i1 = T.axis.spatial(
                                                    (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                                    i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                                    + i0_i1_fused_1_1 * processed_rows_per_thread
                                                    + i0_i1_fused_1_2_init,
                                                )
                                                v_i2 = T.axis.spatial(
                                                    T.int64(4096),
                                                    i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + i2_2_init,
                                                )
                                                T.reads()
                                                T.writes(
                                                    var_NT_matmul_intermediate_pad_rf_local[
                                                        T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                    ]
                                                )
                                                var_NT_matmul_intermediate_pad_rf_local[
                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                ] = T.float16(0)
                                    for k_0 in range(T.int64(r_outter_loop)):
                                        for ax0 in range(T.int64(1)):
                                            for ax1 in T.vectorized(T.int64(vectorize_factor)):
                                                with T.block("lv51_local"):
                                                    v0 = T.axis.spatial(T.int64(344), k_outter * r_outter_loop + k_0 + ax0)
                                                    v1 = T.axis.spatial(
                                                        T.int64(4096),
                                                        i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax1,
                                                    )
                                                    T.reads(lv51[v0, v1])
                                                    T.writes(lv51_local[v0, v1])
                                                    lv51_local[v0, v1] = lv51[v0, v1]
                                        for k_1 in range(T.int64(4)):
                                            for ax0 in range(T.int64(1)):
                                                for ax1 in T.vectorized(vectorize_factor):
                                                    with T.block("lv50_local"):
                                                        v0 = T.axis.spatial(
                                                            T.int64(1376), k_outter * r_outter_loop * T.int64(4) + k_0 * T.int64(4) + k_1 + ax0
                                                        )
                                                        v1 = T.axis.spatial(
                                                            T.int64(4096),
                                                            i2_0 * (ThreadIdx_x * vectorize_factor)
                                                            + i2_1 * vectorize_factor
                                                            + ax1,
                                                        )
                                                        T.reads(lv50[v0, v1])
                                                        T.writes(lv50_local[v0, v1])
                                                        lv50_local[v0, v1] = lv50[v0, v1]
                                            for k_2 in range(T.int64(8)):
                                                for ax0 in range(T.int64(1)):
                                                    for ax1 in T.vectorized(vectorize_factor):
                                                        with T.block("decode"):
                                                            v_i = T.axis.spatial(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2
                                                                + ax0,
                                                            )
                                                            v_j = T.axis.spatial(
                                                                T.int64(4096),
                                                                i2_0 * (ThreadIdx_x * vectorize_factor)
                                                                + i2_1 * vectorize_factor
                                                                + ax1,
                                                            )
                                                            T.reads(
                                                                lv50_local[v_i // T.int64(8), v_j],
                                                                lv51_local[v_i // T.int64(32), v_j],
                                                            )
                                                            T.writes(decode_local[v_i, v_j])
                                                            decode_local[v_i, v_j] = (
                                                                T.Cast(
                                                                    "float16",
                                                                    T.bitwise_and(
                                                                        T.shift_right(
                                                                            lv50_local[
                                                                                v_i // T.int64(8), v_j
                                                                            ],
                                                                            T.Cast(
                                                                                "uint32",
                                                                                v_i % T.int64(8),
                                                                            )
                                                                            * T.uint32(4),
                                                                        ),
                                                                        T.uint32(15),
                                                                    ),
                                                                )
                                                                - T.float16(7)
                                                            ) * lv51_local[v_i // T.int64(32), v_j]
                                                for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                                    for ax2 in T.vectorized(T.int64(1)):
                                                        with T.block("lv5_pad_local"):
                                                            v0 = T.axis.spatial(T.int64(1), ax0)
                                                            v1 = T.axis.spatial(
                                                                (n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                                * T.int64(32)
                                                                + i0_i1_fused_1_1 * processed_rows_per_thread
                                                                + ax1,
                                                            )
                                                            v2 = T.axis.spatial(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2
                                                                + ax2,
                                                            )
                                                            T.reads(lv5[v0, v1, v2])
                                                            T.writes(lv5_pad_local[v0, v1, v2])
                                                            lv5_pad_local[v0, v1, v2] = T.if_then_else(
                                                                v1 < n, lv5[v0, v1, v2], T.float16(0)
                                                            )
                                                for i0_i1_fused_1_2 in range(processed_rows_per_thread):
                                                    for i2_2 in T.vectorized(vectorize_factor):
                                                        with T.block("NT_matmul_update"):
                                                            vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                            v_i0 = T.axis.spatial(
                                                                T.int64(1), T.int64(0)
                                                            )
                                                            v_i1 = T.axis.spatial(
                                                                (n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                i0_i1_fused_0_i0_i1_fused_1_0_fused
                                                                * T.int64(32)
                                                                + i0_i1_fused_1_1 * processed_rows_per_thread
                                                                + i0_i1_fused_1_2,
                                                            )
                                                            v_i2 = T.axis.spatial(
                                                                T.int64(4096),
                                                                i2_0 * (ThreadIdx_x * vectorize_factor)
                                                                + i2_1 * vectorize_factor
                                                                + i2_2,
                                                            )
                                                            v_k = T.axis.reduce(
                                                                T.int64(11008),
                                                                k_outter * r_outter_loop * T.int64(32)
                                                                + k_0 * T.int64(32)
                                                                + k_1 * T.int64(8)
                                                                + k_2,
                                                            )
                                                            T.reads(
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ],
                                                                lv5_pad_local[v_i0, v_i1, v_k],
                                                                decode_local[v_k, v_i2],
                                                            )
                                                            T.writes(
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ]
                                                            )
                                                            var_NT_matmul_intermediate_pad_rf_local[
                                                                T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                            ] = (
                                                                var_NT_matmul_intermediate_pad_rf_local[
                                                                    T.int64(vk_outter_0), v_i0, v_i1, v_i2
                                                                ]
                                                                + lv5_pad_local[v_i0, v_i1, v_k]
                                                                * decode_local[v_k, v_i2]
                                                            )
                                    for ax0, ax1 in T.grid(T.int64(1), processed_rows_per_thread):
                                        for ax2 in T.vectorized(vectorize_factor):
                                            with T.block("var_NT_matmul_intermediate_pad_local"):
                                                vk_outter_0 = T.axis.spatial(T.int64(rsplit_factor), k_outter)
                                                v0 = T.axis.spatial(T.int64(1), ax0)
                                                v1 = T.axis.spatial(
                                                    (n + T.int64(31)) // T.int64(32) * T.int64(32),
                                                    i0_i1_fused_0_i0_i1_fused_1_0_fused * T.int64(32)
                                                    + i0_i1_fused_1_1 * processed_rows_per_thread
                                                    + ax1,
                                                )
                                                v2 = T.axis.spatial(
                                                    T.int64(4096),
                                                    i2_0 * (ThreadIdx_x * vectorize_factor) + i2_1 * vectorize_factor + ax2,
                                                )
                                                T.reads(
                                                    lv3[v0, v1, v2],
                                                    var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2],
                                                )
                                                T.writes(var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2])
                                                if v1 < n:
                                                    var_NT_matmul_intermediate_pad_rf[T.int64(vk_outter_0), v0, v1, v2] = (
                                                        var_NT_matmul_intermediate_pad_rf_local[T.int64(vk_outter_0), v0, v1, v2]
                                                        )
                ## sum(sub_reduce), sub_reduce shape: [rfactor, 1, n, 4096]
                ### reuduce axis: rfactor
                ### spatial axes: [1, n, 4096]
                #### threadIndex 划分:
                ## blockIdx.y: 处理by个32行数据
                ## blockIdx.x: 和tx及vfactor配合, 处理4096个columns数据, 也可能处理多行(rows_per_thread)
                ## threadIdx.x: ref to blockIdx.x
                ## threadIdx.y: 与rows_per_thread配合处理32行数据
                REDUCE_BX = bx
                REDUCE_TX = tx
                REDUCE_TY = ty
                REDUCE_VFACTOR = vf
                REDUCE_ROWS_PER_THREAD = pr
                for sp_row_by in T.thread_binding(
                    (n + T.int64(31)) // T.int64(32), thread="blockIdx.y"
                ):
                    for sp_col_bx in T.thread_binding(T.int64(REDUCE_BX), thread="blockIdx.x"):
                        for sp_col_tx in T.thread_binding(T.int64(REDUCE_TX), thread="threadIdx.x"):
                            for sp_row_ty in T.thread_binding(T.int64(REDUCE_TY), thread="threadIdx.y"):
                                for ax0, ax1 in T.grid(T.int64(1), REDUCE_ROWS_PER_THREAD):
                                    for sp_col_vfactor in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                        for k_0_0 in range(T.int64(rsplit_factor)):
                                            with T.block("matmul_update"):
                                                vk_0_0 = T.axis.reduce(T.int64(rsplit_factor), k_0_0)
                                                v_i0 = T.axis.spatial(T.int64(1), T.int64(0))
                                                v_i1 = T.axis.spatial((n + T.int64(31))
                                                                // T.int64(32)
                                                                * T.int64(32),
                                                                sp_row_by * T.int64(32)
                                                                + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                                + ax1)
                                                v_i2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + sp_col_vfactor)
                                                T.reads(var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2])
                                                T.writes(var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2])
                                                with T.init():
                                                    var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = T.float16(0)
                                                var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] = var_NT_matmul_intermediate_pad_local[v_i0, v_i1, v_i2] + var_NT_matmul_intermediate_pad_rf[vk_0_0, v_i0, v_i1, v_i2]
                                for ax0, ax1 in T.grid(T.int64(1), T.int64(REDUCE_ROWS_PER_THREAD)):
                                    for ax2 in T.vectorized(T.int64(REDUCE_VFACTOR)):
                                        with T.block("output"):
                                            v0 = T.axis.spatial(T.int64(1), T.int64(0))
                                            v1 = T.axis.spatial((n + T.int64(31))
                                                            // T.int64(32)
                                                            * T.int64(32),
                                                            sp_row_by * T.int64(32)
                                                            + sp_row_ty * REDUCE_ROWS_PER_THREAD
                                                            + ax1)
                                            v2 = T.axis.spatial(T.int64(4096), sp_col_bx * (REDUCE_TX * REDUCE_VFACTOR) + sp_col_tx * REDUCE_VFACTOR + ax2)
                                            T.reads(lv3[v0, v1, v2], p_output0_intermediate[v0, v1, v2])
                                            T.writes(p_output0_intermediate[v0, v1, v2])
                                            if v1 < n:
                                                p_output0_intermediate[v0, v1, v2] = (lv3[v0, v1, v2]
                                                                    + var_NT_matmul_intermediate_pad_local[v0, v1, v2])
        return tvm.tir.Schedule(ModuleToManual).mod

    BlockIdx_x = [None] # 32
    # n = 32
    # BlockIdx_y = (n+31)//32 * 32 # 这里32是假设输入为32的倍数, //32的32 = thready * 
    ThreadIdx_x = [16, 32, 48, 64, 96, 128, 192, 256, 384, 512]#16 * 3
    # ThreadIdx_y = 8 # = 32 / processed_rows_per_thread
    vectorize_factor = [2, 4, 8]# 8
    # processed_columns_per_thread = vectorize_factor# w_y / (BlockIdx_x * ThreadIdx_x) == vectorize_factor
    processed_rows_per_thread = [1, 2, 4, 8, 16]#4
    task_index = 0
    total_task_num = len(vectorize_factor)*len(BlockIdx_x)*len(ThreadIdx_x)*len(processed_rows_per_thread)
    records = {}
    print(f"Total tasks: {total_task_num}")
    # try:
    vectorize_factor_r = vectorize_factor[::-1]
    processed_rows_per_thread_r = processed_rows_per_thread[::-1]
    ThreadIdx_x_r = ThreadIdx_x[::-1]
    # table
    write_interval = 5
    from prettytable import PrettyTable
    table = PrettyTable()
    table.field_names = ["vectorize_factor", "processed_rows_per_thread", "blockIdx.x", "threadIdx.x", "threadIdx.y", "cost(ms)"]
    for vf in vectorize_factor_r:
        for pr in processed_rows_per_thread_r:
            for tx in ThreadIdx_x_r:
                task_index = task_index + 1
                import math
                bx = math.ceil(w_y /(vf * tx))
                ty = math.ceil(32//pr)
                if bx * tx * vf > w_y or tx*ty > 1024 or 32 % pr != 0: # w_y为输出列数, 工作组和vectorize相乘不能大于该数字
                    print(f"search record [{task_index}/{total_task_num}]: skip {vf} {pr} {bx} {tx} {ty}")
                    continue
                if w_y % (vf * tx) != 0:
                    print(f"search record [{task_index}/{total_task_num}]: skip because bx isn't divisible {vf} {pr} {bx} {tx} {ty}")
                    continue
                print(f"search record [{task_index}/{total_task_num}]: start run {vf} {pr} {bx} {tx} {ty}")
                # vf: int, pr: int, bx: int, tx: int, ty: int):
                mod_deploy = search(vf, pr, bx, tx, ty)
                cost = test_opencl(mod_deploy, "search")
                print("=====")
                records[(vf, pr, bx, tx, ty)] = cost
                table.add_row([vf, pr, bx, tx, ty, cost])
                if task_index % write_interval == 0:
                    with open(record_file, 'wt') as f:
                        f.write(table.get_csv_string())
    print("================================")
    print(table)
    with open(record_file, 'wt') as f:
        f.write(table.get_csv_string())
    
    # record_sorted = sorted(record.items(), key=lambda x: x[1][0], reverse=True)
auto_tune_allreduce("./manual_tune/down_n_split_reduce_tune_record_allreduce_1.csv")
# Out:
# Total tasks: 150
# search record [1/150]: start run 8 16 1 512 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# /data/workspace/llm/github/new_wksp/tvm-unity/python/tvm/driver/build_module.py:264: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.960080ms with loop 32
# evaluator[search] GEMV-Blocking: 176.493199GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [2/150]: skip 8 16 2 384 2
# search record [3/150]: start run 8 16 2 256 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.729416ms with loop 32
# evaluator[search] GEMV-Blocking: 182.542851GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [4/150]: skip 8 16 3 192 2
# search record [5/150]: start run 8 16 4 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.667264ms with loop 32
# evaluator[search] GEMV-Blocking: 184.244509GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [6/150]: skip 8 16 6 96 2
# search record [7/150]: start run 8 16 8 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.630072ms with loop 32
# evaluator[search] GEMV-Blocking: 185.278046GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [8/150]: skip 8 16 11 48 2
# search record [9/150]: start run 8 16 16 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.622416ms with loop 32
# evaluator[search] GEMV-Blocking: 185.492241GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [10/150]: start run 8 16 32 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.608872ms with loop 32
# evaluator[search] GEMV-Blocking: 185.872382GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [11/150]: skip 8 8 1 512 4
# search record [12/150]: skip 8 8 2 384 4
# search record [13/150]: start run 8 8 2 256 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.668576ms with loop 32
# evaluator[search] GEMV-Blocking: 184.208260GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [14/150]: skip 8 8 3 192 4
# search record [15/150]: start run 8 8 4 128 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.587088ms with loop 32
# evaluator[search] GEMV-Blocking: 186.487077GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [16/150]: skip 8 8 6 96 4
# search record [17/150]: start run 8 8 8 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.566928ms with loop 32
# evaluator[search] GEMV-Blocking: 187.059579GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [18/150]: skip 8 8 11 48 4
# search record [19/150]: start run 8 8 16 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.568616ms with loop 32
# evaluator[search] GEMV-Blocking: 187.011508GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [20/150]: start run 8 8 32 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.564624ms with loop 32
# evaluator[search] GEMV-Blocking: 187.125231GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [21/150]: skip 8 4 1 512 8
# search record [22/150]: skip 8 4 2 384 8
# search record [23/150]: skip 8 4 2 256 8
# search record [24/150]: skip 8 4 3 192 8
# search record [25/150]: start run 8 4 4 128 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.579560ms with loop 32
# evaluator[search] GEMV-Blocking: 186.700446GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [26/150]: skip 8 4 6 96 8
# search record [27/150]: start run 8 4 8 64 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.547304ms with loop 32
# evaluator[search] GEMV-Blocking: 187.620246GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [28/150]: skip 8 4 11 48 8
# search record [29/150]: start run 8 4 16 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.550784ms with loop 32
# evaluator[search] GEMV-Blocking: 187.520575GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [30/150]: start run 8 4 32 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.545512ms with loop 32
# evaluator[search] GEMV-Blocking: 187.671611GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [31/150]: skip 8 2 1 512 16
# search record [32/150]: skip 8 2 2 384 16
# search record [33/150]: skip 8 2 2 256 16
# search record [34/150]: skip 8 2 3 192 16
# search record [35/150]: skip 8 2 4 128 16
# search record [36/150]: skip 8 2 6 96 16
# search record [37/150]: start run 8 2 8 64 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.548960ms with loop 32
# evaluator[search] GEMV-Blocking: 187.572803GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [38/150]: skip 8 2 11 48 16
# search record [39/150]: start run 8 2 16 32 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.551168ms with loop 32
# evaluator[search] GEMV-Blocking: 187.509584GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [40/150]: start run 8 2 32 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.542528ms with loop 32
# evaluator[search] GEMV-Blocking: 187.757207GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [41/150]: skip 8 1 1 512 32
# search record [42/150]: skip 8 1 2 384 32
# search record [43/150]: skip 8 1 2 256 32
# search record [44/150]: skip 8 1 3 192 32
# search record [45/150]: skip 8 1 4 128 32
# search record [46/150]: skip 8 1 6 96 32
# search record [47/150]: skip 8 1 8 64 32
# search record [48/150]: skip 8 1 11 48 32
# search record [49/150]: start run 8 1 16 32 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.549352ms with loop 32
# evaluator[search] GEMV-Blocking: 187.561576GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [50/150]: start run 8 1 32 16 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.543448ms with loop 32
# evaluator[search] GEMV-Blocking: 187.730809GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [51/150]: start run 4 16 2 512 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.678344ms with loop 32
# evaluator[search] GEMV-Blocking: 183.938830GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [52/150]: skip 4 16 3 384 2
# search record [53/150]: start run 4 16 4 256 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.591832ms with loop 32
# evaluator[search] GEMV-Blocking: 186.352866GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [54/150]: skip 4 16 6 192 2
# search record [55/150]: start run 4 16 8 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.577552ms with loop 32
# evaluator[search] GEMV-Blocking: 186.757442GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [56/150]: skip 4 16 11 96 2
# search record [57/150]: start run 4 16 16 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.577224ms with loop 32
# evaluator[search] GEMV-Blocking: 186.766755GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [58/150]: skip 4 16 22 48 2
# search record [59/150]: start run 4 16 32 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.577320ms with loop 32
# evaluator[search] GEMV-Blocking: 186.764029GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [60/150]: start run 4 16 64 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.581080ms with loop 32
# evaluator[search] GEMV-Blocking: 186.657324GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [61/150]: skip 4 8 2 512 4
# search record [62/150]: skip 4 8 3 384 4
# search record [63/150]: start run 4 8 4 256 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.580376ms with loop 32
# evaluator[search] GEMV-Blocking: 186.677294GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [64/150]: skip 4 8 6 192 4
# search record [65/150]: start run 4 8 8 128 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.546528ms with loop 32
# evaluator[search] GEMV-Blocking: 187.642485GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [66/150]: skip 4 8 11 96 4
# search record [67/150]: start run 4 8 16 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.547288ms with loop 32
# evaluator[search] GEMV-Blocking: 187.620704GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [68/150]: skip 4 8 22 48 4
# search record [69/150]: start run 4 8 32 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.544640ms with loop 32
# evaluator[search] GEMV-Blocking: 187.696616GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [70/150]: start run 4 8 64 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.546952ms with loop 32
# evaluator[search] GEMV-Blocking: 187.630333GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [71/150]: skip 4 4 2 512 8
# search record [72/150]: skip 4 4 3 384 8
# search record [73/150]: skip 4 4 4 256 8
# search record [74/150]: skip 4 4 6 192 8
# search record [75/150]: start run 4 4 8 128 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.542704ms with loop 32
# evaluator[search] GEMV-Blocking: 187.752156GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [76/150]: skip 4 4 11 96 8
# search record [77/150]: start run 4 4 16 64 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.542832ms with loop 32
# evaluator[search] GEMV-Blocking: 187.748483GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [78/150]: skip 4 4 22 48 8
# search record [79/150]: start run 4 4 32 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.540872ms with loop 32
# evaluator[search] GEMV-Blocking: 187.804743GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [80/150]: start run 4 4 64 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.540080ms with loop 32
# evaluator[search] GEMV-Blocking: 187.827486GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [81/150]: skip 4 2 2 512 16
# search record [82/150]: skip 4 2 3 384 16
# search record [83/150]: skip 4 2 4 256 16
# search record [84/150]: skip 4 2 6 192 16
# search record [85/150]: skip 4 2 8 128 16
# search record [86/150]: skip 4 2 11 96 16
# search record [87/150]: start run 4 2 16 64 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.543456ms with loop 32
# evaluator[search] GEMV-Blocking: 187.730579GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [88/150]: skip 4 2 22 48 16
# search record [89/150]: start run 4 2 32 32 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.540312ms with loop 32
# evaluator[search] GEMV-Blocking: 187.820823GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [90/150]: start run 4 2 64 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.542456ms with loop 32
# evaluator[search] GEMV-Blocking: 187.759273GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [91/150]: skip 4 1 2 512 32
# search record [92/150]: skip 4 1 3 384 32
# search record [93/150]: skip 4 1 4 256 32
# search record [94/150]: skip 4 1 6 192 32
# search record [95/150]: skip 4 1 8 128 32
# search record [96/150]: skip 4 1 11 96 32
# search record [97/150]: skip 4 1 16 64 32
# search record [98/150]: skip 4 1 22 48 32
# search record [99/150]: start run 4 1 32 32 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.544152ms with loop 32
# evaluator[search] GEMV-Blocking: 187.710613GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [100/150]: start run 4 1 64 16 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.550112ms with loop 32
# evaluator[search] GEMV-Blocking: 187.539814GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [101/150]: start run 2 16 4 512 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.632072ms with loop 32
# evaluator[search] GEMV-Blocking: 185.222172GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [102/150]: skip 2 16 6 384 2
# search record [103/150]: start run 2 16 8 256 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.570320ms with loop 32
# evaluator[search] GEMV-Blocking: 186.963007GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [104/150]: skip 2 16 11 192 2
# search record [105/150]: start run 2 16 16 128 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.569680ms with loop 32
# evaluator[search] GEMV-Blocking: 186.981220GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [106/150]: skip 2 16 22 96 2
# search record [107/150]: start run 2 16 32 64 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.567608ms with loop 32
# evaluator[search] GEMV-Blocking: 187.040211GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [108/150]: skip 2 16 43 48 2
# search record [109/150]: start run 2 16 64 32 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.568464ms with loop 32
# evaluator[search] GEMV-Blocking: 187.015836GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [110/150]: start run 2 16 128 16 2
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.576888ms with loop 32
# evaluator[search] GEMV-Blocking: 186.776297GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [111/150]: skip 2 8 4 512 4
# search record [112/150]: skip 2 8 6 384 4
# search record [113/150]: start run 2 8 8 256 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.546032ms with loop 32
# evaluator[search] GEMV-Blocking: 187.656703GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [114/150]: skip 2 8 11 192 4
# search record [115/150]: start run 2 8 16 128 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.545920ms with loop 32
# evaluator[search] GEMV-Blocking: 187.659914GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [116/150]: skip 2 8 22 96 4
# search record [117/150]: start run 2 8 32 64 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.542832ms with loop 32
# evaluator[search] GEMV-Blocking: 187.748483GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [118/150]: skip 2 8 43 48 4
# search record [119/150]: start run 2 8 64 32 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.543200ms with loop 32
# evaluator[search] GEMV-Blocking: 187.737924GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [120/150]: start run 2 8 128 16 4
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.547544ms with loop 32
# evaluator[search] GEMV-Blocking: 187.613368GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [121/150]: skip 2 4 4 512 8
# search record [122/150]: skip 2 4 6 384 8
# search record [123/150]: skip 2 4 8 256 8
# search record [124/150]: skip 2 4 11 192 8
# search record [125/150]: start run 2 4 16 128 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.549680ms with loop 32
# evaluator[search] GEMV-Blocking: 187.552183GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [126/150]: skip 2 4 22 96 8
# search record [127/150]: start run 2 4 32 64 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.548224ms with loop 32
# evaluator[search] GEMV-Blocking: 187.593886GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [128/150]: skip 2 4 43 48 8
# search record [129/150]: start run 2 4 64 32 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.547608ms with loop 32
# evaluator[search] GEMV-Blocking: 187.611534GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [130/150]: start run 2 4 128 16 8
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.551976ms with loop 32
# evaluator[search] GEMV-Blocking: 187.486460GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [131/150]: skip 2 2 4 512 16
# search record [132/150]: skip 2 2 6 384 16
# search record [133/150]: skip 2 2 8 256 16
# search record [134/150]: skip 2 2 11 192 16
# search record [135/150]: skip 2 2 16 128 16
# search record [136/150]: skip 2 2 22 96 16
# search record [137/150]: start run 2 2 32 64 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.544264ms with loop 32
# evaluator[search] GEMV-Blocking: 187.707401GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [138/150]: skip 2 2 43 48 16
# search record [139/150]: start run 2 2 64 32 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.544696ms with loop 32
# evaluator[search] GEMV-Blocking: 187.695010GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [140/150]: start run 2 2 128 16 16
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.544368ms with loop 32
# evaluator[search] GEMV-Blocking: 187.704418GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [141/150]: skip 2 1 4 512 32
# search record [142/150]: skip 2 1 6 384 32
# search record [143/150]: skip 2 1 8 256 32
# search record [144/150]: skip 2 1 11 192 32
# search record [145/150]: skip 2 1 16 128 32
# search record [146/150]: skip 2 1 22 96 32
# search record [147/150]: skip 2 1 32 64 32
# search record [148/150]: skip 2 1 43 48 32
# search record [149/150]: start run 2 1 64 32 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.549800ms with loop 32
# evaluator[search] GEMV-Blocking: 187.548747GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# search record [150/150]: start run 2 1 128 16 32
# Build ...
# Run GPU(OpenCL Flavor) test ...
# Connect to device done.
# evaluator[search] GEMV-Blocking: 6.564296ms with loop 32
# evaluator[search] GEMV-Blocking: 187.134581GFLOPS
# [[[-18592. -20576. -18896. ... -18112. -18512. -18240.]
#   [-18592. -20624. -19088. ... -18240. -18704. -18336.]
#   [-18736. -20608. -18960. ... -18384. -18592. -18304.]
#   ...
#   [-18864. -20832. -19008. ... -18400. -18912. -18352.]
#   [-18496. -20448. -18944. ... -18160. -18560. -18048.]
#   [-18720. -20720. -19184. ... -18176. -18816. -18256.]]]
# [-18592. -20576. -18896. -18624. -18944. -19904. -18656. -18816. -17632.
#  -18384. -18992. -18480. -19744. -19904. -19840. -19296. -19536. -18224.
#  -19040. -18752.]
# =====
# ================================
# +------------------+---------------------------+------------+-------------+-------------+----------+
# | vectorize_factor | processed_rows_per_thread | blockIdx.x | threadIdx.x | threadIdx.y | cost(ms) |
# +------------------+---------------------------+------------+-------------+-------------+----------+
# |        8         |             16            |     1      |     512     |      2      | 6.96008  |
# |        8         |             16            |     2      |     256     |      2      | 6.729416 |
# |        8         |             16            |     4      |     128     |      2      | 6.667264 |
# |        8         |             16            |     8      |      64     |      2      | 6.630072 |
# |        8         |             16            |     16     |      32     |      2      | 6.622416 |
# |        8         |             16            |     32     |      16     |      2      | 6.608872 |
# |        8         |             8             |     2      |     256     |      4      | 6.668576 |
# |        8         |             8             |     4      |     128     |      4      | 6.587088 |
# |        8         |             8             |     8      |      64     |      4      | 6.566928 |
# |        8         |             8             |     16     |      32     |      4      | 6.568616 |
# |        8         |             8             |     32     |      16     |      4      | 6.564624 |
# |        8         |             4             |     4      |     128     |      8      | 6.57956  |
# |        8         |             4             |     8      |      64     |      8      | 6.547304 |
# |        8         |             4             |     16     |      32     |      8      | 6.550784 |
# |        8         |             4             |     32     |      16     |      8      | 6.545512 |
# |        8         |             2             |     8      |      64     |      16     | 6.54896  |
# |        8         |             2             |     16     |      32     |      16     | 6.551168 |
# |        8         |             2             |     32     |      16     |      16     | 6.542528 |
# |        8         |             1             |     16     |      32     |      32     | 6.549352 |
# |        8         |             1             |     32     |      16     |      32     | 6.543448 |
# |        4         |             16            |     2      |     512     |      2      | 6.678344 |
# |        4         |             16            |     4      |     256     |      2      | 6.591832 |
# |        4         |             16            |     8      |     128     |      2      | 6.577552 |
# |        4         |             16            |     16     |      64     |      2      | 6.577224 |
# |        4         |             16            |     32     |      32     |      2      | 6.57732  |
# |        4         |             16            |     64     |      16     |      2      | 6.58108  |
# |        4         |             8             |     4      |     256     |      4      | 6.580376 |
# |        4         |             8             |     8      |     128     |      4      | 6.546528 |
# |        4         |             8             |     16     |      64     |      4      | 6.547288 |
# |        4         |             8             |     32     |      32     |      4      | 6.54464  |
# |        4         |             8             |     64     |      16     |      4      | 6.546952 |
# |        4         |             4             |     8      |     128     |      8      | 6.542704 |
# |        4         |             4             |     16     |      64     |      8      | 6.542832 |
# |        4         |             4             |     32     |      32     |      8      | 6.540872 |
# |        4         |             4             |     64     |      16     |      8      | 6.54008  |
# |        4         |             2             |     16     |      64     |      16     | 6.543456 |
# |        4         |             2             |     32     |      32     |      16     | 6.540312 |
# |        4         |             2             |     64     |      16     |      16     | 6.542456 |
# |        4         |             1             |     32     |      32     |      32     | 6.544152 |
# |        4         |             1             |     64     |      16     |      32     | 6.550112 |
# |        2         |             16            |     4      |     512     |      2      | 6.632072 |
# |        2         |             16            |     8      |     256     |      2      | 6.57032  |
# |        2         |             16            |     16     |     128     |      2      | 6.56968  |
# |        2         |             16            |     32     |      64     |      2      | 6.567608 |
# |        2         |             16            |     64     |      32     |      2      | 6.568464 |
# |        2         |             16            |    128     |      16     |      2      | 6.576888 |
# |        2         |             8             |     8      |     256     |      4      | 6.546032 |
# |        2         |             8             |     16     |     128     |      4      | 6.54592  |
# |        2         |             8             |     32     |      64     |      4      | 6.542832 |
# |        2         |             8             |     64     |      32     |      4      |  6.5432  |
# |        2         |             8             |    128     |      16     |      4      | 6.547544 |
# |        2         |             4             |     16     |     128     |      8      | 6.54968  |
# |        2         |             4             |     32     |      64     |      8      | 6.548224 |
# |        2         |             4             |     64     |      32     |      8      | 6.547608 |
# |        2         |             4             |    128     |      16     |      8      | 6.551976 |
# |        2         |             2             |     32     |      64     |      16     | 6.544264 |
# |        2         |             2             |     64     |      32     |      16     | 6.544696 |
# |        2         |             2             |    128     |      16     |      16     | 6.544368 |
# |        2         |             1             |     64     |      32     |      32     |  6.5498  |
# |        2         |             1             |    128     |      16     |      32     | 6.564296 |
# +------------------+---------------------------+------------+-------------+-------------+----------+

# %%
import numpy as np
target = tvm.target.Target("opencl -device=adreno", host="llvm -mtriple=aarch64-linux-gnu")
device_key="android"
rpc_host = "10.158.176.30"
rpc_port = 5001
# remote = autotvm.measure.request_remote(device_key, "10.158.176.30", 5001, timeout=10000)
# dev = remote.device(str(target), 0)

# num_flop = 1228406784
# W_np = np.random.uniform(size=(512, vocab_size)).astype("uint32")
# S_np = np.random.uniform(size=(128, vocab_size)).astype("float16")
# Input_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# # Output_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# W_nd = tvm.nd.array(W_np, dev)
# S_nd = tvm.nd.array(S_np, dev)
# Input_nd = tvm.nd.array(Input_np, dev)
# Output_nd = tvm.nd.array(np.zeros((1, 1, vocab_size), dtype="float32"), dev)

# %%
rpc_config = ms.runner.RPCConfig(tracker_host=rpc_host, tracker_port=rpc_port, tracker_key = device_key)
runner= ms.runner.RPCRunner(rpc_config)
# ms.builder.LocalBuilder()
sch = tvm.tir.Schedule(ModuleSrc)
database = ms.tune_tir(
    mod=ModuleSrc,
    target=target,
    max_trials_global=64,
    num_trials_per_iter=64,
    work_dir="./tune_first",
    cost_model="xgb",
    runner = runner
)
print(len(database))
sch1 = ms.tir_integration.compile_tir(database, sch.mod, target)
print(type(sch1))

# %%
from tvm.script import relax as R
@I.ir_module
class Module:
    @R.function
    def main(A: R.Tensor((3, 4), dtype="float32"), B: R.Tensor((4, 5), dtype="float32")):
        with R.dataflow():
            lv: R.Tensor((3, 5), dtype="float32") = R.matmul(A, B)
            gv: R.Tensor((3, 5), dtype="float32") = lv
            R.output(gv)
        return gv

# %%
## auto_scheduler test
from tvm import auto_scheduler
import numpy as np
a_np = np.random.rand(3, 4).astype("float32")
b_np = np.random.rand(4, 5).astype("float32")
a_nd = tvm.runtime.NDArray(a_np)
b_nd = tvm.runtime.NDArray(b_np)
sch = tvm.tir.Schedule(Module)

params = {"A": a_np, "B": b_np}
## 报错，这里只支持relay
# tasks = auto_scheduler.extract_tasks(sch.mod, params, target=target)
tasks = ms.relax_integration.extract_tasks(sch.mod, target=target, params=params)
print(len(tasks))

# %%
from mod_deploy import Module as ModuleAll
params_all = {}
tasks_all = auto_scheduler.extract_tasks(ModuleAll, params_all, target=target)
print(len(tasks_all))

# %%
import numpy as np
log_file = "tune.json"
def _detect_local_cuda():
    dev = tvm.cuda()
    if not dev.exist:
        return None
    return tvm.target.Target(
        {
            "kind": "cuda",
            "max_shared_memory_per_block": dev.max_shared_memory_per_block,
            "max_threads_per_block": dev.max_threads_per_block,
            "thread_warp_size": dev.warp_size,
            "registers_per_block": 65536,
            "arch": "sm_" + tvm.cuda().compute_version.replace(".", ""),
        }
    )
# target = tvm.target.Target("cuda", host="llvm")
target = _detect_local_cuda()

print(target)
# 定义计算任务
dev = tvm.cuda(0)

num_flop = 1228406784
W_np = np.random.uniform(size=(512, vocab_size)).astype("uint32")
S_np = np.random.uniform(size=(128, vocab_size)).astype("float16")
Input_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
# Output_np = np.random.uniform(size=(1, 1, 4096)).astype("float16")
W_nd = tvm.nd.array(W_np, dev)
S_nd = tvm.nd.array(S_np, dev)
Input_nd = tvm.nd.array(Input_np, dev)
Output_nd = tvm.nd.array(np.zeros((1, 1, vocab_size), dtype="float32"), dev)
sch = tvm.tir.Schedule(ModuleSrc)
new_mod = sch.mod

# %%
# task = auto_scheduler.SearchTask(func=sch.mod['fused_fused_decode11_fused_matmul5_cast2'], args=sch.mod['fused_fused_decode11_fused_matmul5_cast2'].params, target=target)

# tune_option = auto_scheduler.TuningOptions(
#     num_measure_trials=10,
#     measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
#     verbose=2,
# )


database = ms.tune_tir(
    mod=new_mod,
    target=target,
    max_trials_global=64,
    num_trials_per_iter=64,
    work_dir="./tune_45593_1",
    cost_model="xgb"
)
print(len(database))
sch1 = ms.tir_integration.compile_tir(database, new_mod, target)
print(type(sch1))

# %%
# print(sch1.trace)
# print(sch1.mod.script())
rt_mod = tvm.build(sch1.mod, target="cuda")

evaluator = rt_mod.time_evaluator("main", dev, number=100)

print("evaluator GEMV-Blocking: %f GFLOPS" % (1228406784 / evaluator(W_nd, S_nd, Input_nd, Output_nd).mean / 1e9))

# %%
record_database = ms.Database.create(kind='json', work_dir='./tune_45593_1')

# %%
record_sch = ms.tir_integration.compile_tir(record_database, new_mod, target)

record_rt_mod = tvm.build(record_sch.mod, target="cuda")

record_evaluator = record_rt_mod.time_evaluator("main", dev, number=20)

print("evaluator GEMV-Blocking: %f GFLOPS" % (num_flop / record_evaluator(W_nd, S_nd, Input_nd, Output_nd).mean / 1e9))
print(record_sch.trace)
print(record_sch.mod.script())

# %%
from typing import TYPE_CHECKING, Dict, List, Optional, Union, Callable
from tvm import runtime
if TYPE_CHECKING:
    import numpy as np  # type: ignore
    from tvm.ir import IRModule
    from tvm.meta_schedule.runner import EvaluatorConfig, RPCConfig
    from tvm.runtime import Device, Module, NDArray
    from tvm.target import Target
    from tvm.runtime.vm import Executable


def f_measurement(
    rt_mod: runtime.Module, device: runtime.ndarray.Device, input_data: Dict[str, runtime.NDArray]
):
    vm = relax.VirtualMachine(rt_mod, device=device)
    vm.save_function("main", "measure_func", **input_data, include_return=False)
    evaluator = vm.time_evaluator(
        func_name="measure_func",
        dev=device,
        repeat=100,
        number=1,
        min_repeat_ms=500,
    )
    return evaluator()

def run_module_via_rpc(
    rpc_config: "RPCConfig",
    lib: Union["Module", "Executable"],
    dev_type: str,
    args: Union[Dict[int, "np.ndarray"], Dict[str, "np.ndarray"]],
    continuation: Callable,
    backend: Optional[str] = "graph",
):
    """Execute a tvm.runtime.Module on RPC remote"""
    # pylint: disable=import-outside-toplevel
    import os
    import tempfile

    from tvm.contrib.tar import tar
    from tvm.runtime import ndarray

    # pylint: enable=import-outside-toplevel

    with tempfile.TemporaryDirectory() as tmp_dir:
        # filename = os.path.join(tmp_dir, "tvm_tmp_mod." + tar.output_format)
        filename = os.path.join(tmp_dir, "tvm_tmp_mod." + "so")
        if backend == "vm":
            code, lib = lib.save(filename, fmt="so")
        from tvm.contrib import ndk
        lib.export_library(filename, ndk.create_shared)
        session = rpc_config.connect_server()
        print(type(session._sess))
        session.upload(filename)
        _, filename = os.path.split(filename)
        rt_mod = session.load_module(filename)
        
        if backend == "vm":
            rt_mod = session.get_function("runtime.Load_Executable")(code, rt_mod)
            # rt_mod = session.get_function("runtime.module.loadfile_relax.Executable")(filename)
        dev = session.device(dev_type=dev_type, dev_id=0)
        # print(dev)
        # create the remote runtime module
        print(rt_mod)
        print(rt_mod['main'])
        from tvm.contrib import graph_executor as runtime
        module = runtime.GraphModule(rt_mod["main"](dev))
        print(module)
        for k, v in args.items():
            module.set_input(k, tvm.nd.array(v))
        return module.run()
        # nd_args = {k: ndarray.array(v, dev) for k, v in args.items()}
        nd_args = {k: ndarray.empty(v.shape, v.dtype, dev) for k, v in args.items()}
        return continuation(rt_mod, dev, nd_args)
